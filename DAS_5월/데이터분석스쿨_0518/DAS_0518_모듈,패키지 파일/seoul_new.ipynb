# %%
# 파일명 seoul.new

class SeoulPkg:
  def detail(self):
    print("[서울 도심 패키지] 호캉스 100만원")

if __name__ == "__main__":
  print("seoul 모듈 직접 실행되었습니다.")
  trip_seoul = SeoulPkg()
  trip_seoul.detail()
else:
  print("외부에서 seoul 모듈 실행되었습니다.")
# Out:
# seoul 모듈 직접 실행되었습니다.
# [서울 도심 패키지] 호캉스 100만원
