# %% [markdown]
# # *args **kwargs 사용하는 이유
#
# * 어떤 입력이든 에러 없이 어떤 값이든 받도록 도와주기 위함

# %%
def test(*arg, **kwarg)

# %%
# *arg 예제 1.

def add(x,y):
  return x + y

add(3,4)
# Out:
# 7

# %%
add(3,4,7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-f8c829071e07> in <cell line: 1>()
# ----> 1 add(3,4,7)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
def add(*x):
  return sum(x)

add(1,3,5)
# Out:
# 9

# %%
add(3,5,7,9,11,13,15,17,19)
# Out:
# 99

# %%
## **는???

add(1,2, x = "3")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-19506c60dad7> in <cell line: 3>()
#       1 ## **는???
#       2
# ----> 3 add(1,2, x = "3")
#
# TypeError: add() got an unexpected keyword argument 'x'

# %%
def add_2(*x, y = "0"):
  return sum(x) + int(y) #"3"-> 3 

add_2(1,2, y = "3")
# Out:
# 6

# %%
add_2(1,2, y = "3", z = "4")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-a28a0345103d> in <cell line: 1>()
# ----> 1 add_2(1,2, y = "3", z = "4")
#
# TypeError: add_2() got an unexpected keyword argument 'z'

# %%
# 2. **의 사용방법

def param(**kwargs):
  print(kwargs)

# %%
param(max_depth = 0.6)
# Out:
# {'max_depth': 0.6}

# %%
param(max_depth = 0.6 , gamma = 3)
# Out:
# {'max_depth': 0.6, 'gamma': 3}

# %%
## 그래서 두가지를 같이 쓰게 되면

def function(*a, **b):
  print(a)
  print(b)

# 어떻게든 오류가 나지 않고, 값을 받아오겠다.

# 1. 어떤 값이 나올까? 
# 2. 이 값은 어떤 자료형태인가? 리스트, 튜플, 셋, 딕셔너리

function(41)
# Out:
# (41,)
# {}

# %%
function(1,2,3,4,5)
# Out:
# (1, 2, 3, 4, 5)
# {}

# %%
function(x=3)
# Out:
# ()
# {'x': 3}

# %%
function(x=3, y=4)
# Out:
# ()
# {'x': 3, 'y': 4}

# %%
function(1,2,3,4,5, x=3, y=4)
# Out:
# (1, 2, 3, 4, 5)
# {'x': 3, 'y': 4}

# %%
function(x=3,y=4, 1,2,3,4,5)
# Out:
#   File "<ipython-input-24-9b6e2d02f98b>", line 1
#     function(x=3,y=4,1,2,3,4,5)
#                               ^
# SyntaxError: positional argument follows keyword argument

# %%
function(a=4)
# Out:
# ()
# {'a': 4}

# %% [markdown]
# # args / kwangs
#
# https://engineer-mole.tistory.com/279
#
# 파이썬 함수에서는 인수 개수를 변경할 수 있다.
# 위치 인수에 대해 첫번째, 두번째는 필수, 세번째 이후는 선택으로 정할 수 있는데, 임의로 개수가 변하는 인수를 가변 길이 인수라 부르고, *를 붙이면 가변 길이 인수가 된다. 지정한 인수가 튜플로 지정이 되고, args라는 변수명을 많이 사용한다.
#
# * 결국 동시에 여러 입력값을 주고 싶을때 사용한다.
# * 아무 이름이나 사용해도 되긴한다. *만 붙이면
# * Tuple처럼 사용이 가능하다. 굳이 리스트나 튜플로 변경하지 않아도 된다.
# * 가변인자는 들어오는 인자의 갯수가 언제나 변할 수 있다.

# %% [markdown]
# # args 예시

# %% [markdown]
# ## args 예시 1

# %%
# args 예시 1
def a_test(a, *args) :
  print(a, args)

a_test(1, 2, 3, 4, 5, 6)

# a= 1 *args = 2-6
# Out:
# 1 (2, 3, 4, 5, 6)

# %% [markdown]
# ## args 예시 2

# %%
# args 예시 2
# 변수 앞에 별표를 붙이는건 언패킹

def c_test(a, args):
  print(a, *args)  # print문에서 사용된 args는 변수명

c_test(1, (2, 3, 4, 5, 6))
# Out:
# 1 2 3 4 5 6

# %%
# args 앞에 별표를 붙이는건 패킹

def c_test(a, *args):
  print(a, args)
  
c_test(1, (2, 3, 4, 5, 6))
# Out:
# 1 ((2, 3, 4, 5, 6),)

# %%
# args와 변수 앞에 둘 다 별표를 붙이면 그대로 나옴

def c_test(a, *args):
  print(a, *args)
  
c_test(1, (2, 3, 4, 5, 6))
# Out:
# 1 (2, 3, 4, 5, 6)

# %%
# 변수의 언패킹
a, b, c = [[1, 2], [3, 4], [5, 6]]

print(a, b, c)
# Out:
# [1, 2] [3, 4] [5, 6]

# %%
data = [[1, 2], [3, 4], [5, 6]]
print(*data)
# Out:
# [1, 2] [3, 4] [5, 6]

# %% [markdown]
# # kwargs 예시

# %% [markdown]
# ## kwargs 예시 1

# %%
# kwargs 예시 1
# 헷갈리지 말라고 내주신 문제!

def b_test(a, *kwargs):
  print(a, kwargs)

b_test(1, b=2, c=3, d=4, e=5, f=6)

# kwargs 앞에 *이 한 개일 때는 에러가 남
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-2eb8ca138ef3> in <cell line: 7>()
#       5   print(a, kwargs)
#       6
# ----> 7 b_test(1, b=2, c=3, d=4, e=5, f=6)
#
# TypeError: b_test() got an unexpected keyword argument 'b'

# %%
def c_test(a, **kwargs):
  print(a, kwargs)

c_test(1, b=2, c=3, d=4, e=5, f=6)

# 별이 두 개일 때는 잘 나옴
# Out:
# 1 {'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %% [markdown]
# # kwargs
#
# **kwargs는 딕셔너리 형태로 가변인수를 받을 수 있는 방법이다.
#
# 사용방법은 args와 동일하고, args는 튜플형식으로 받지만
# kwargs는 딕셔너리 형태로 받는다는 특징이 있다.

# %%
def print_kwargs(a, **kwargs):
  print(a)
  print(kwargs)
  
  for i in kwargs:
    print(i)

print_kwargs(100, name = 'leehojun', age = 10)
# Out:
# 100
# {'name': 'leehojun', 'age': 10}
# name
# age

# %%
def func(x, y, **kwargs):
  print(f"첫번째 인자는 x")
  print(f"두번째 인자는 y")
  if kwargs:
    print(f"세 번째 이후의 인수 : {kwargs}")

func(x=1, y=2)
# Out:
# 첫번째 인자는 x
# 두번째 인자는 y

# %%
func(x=1, y=2, z=3, w=4)
# Out:
# 첫번째 인자는 x
# 두번째 인자는 y
# 세 번째 이후의 인수 : {'z': 3, 'w': 4}

# %% [markdown]
# # args와 kwargs의 응용
#
# 앞에는 args형식으로 뒤에는 kwargs형식으로 받게되면 정상적으로 작동합니다. 파라미터를 넣을때 순서를 바꾸거나 혼합하면 에러가 발생됩니다.

# %%
# 아래 예제는 파라미터의 값을 선언해서 보내는 형식으로 구성되어 있습니다. 
# 예제 뿐만 아니라 다양하게 실습해 보시기 바랍니다.

def print_args_kwargs(*args, **kwargs):
    print('args:', args)
    for x in args:
        print(x)
    print('kwargs:', kwargs)
    for x in kwargs:
        print(x)
        print(kwargs[x])

inputlist=[100, True, 'leehojun']
inputdic={'score':100, 'name':'leehojun', 'age':'10'}
print_args_kwargs(*inputlist)
print('--------')
print_args_kwargs(**inputdic)
print('--------')
print_args_kwargs(*inputlist, **inputdic)
# Out:
# args: (100, True, 'leehojun')
# 100
# True
# leehojun
# kwargs: {}
# --------
# args: ()
# kwargs: {'score': 100, 'name': 'leehojun', 'age': '10'}
# score
# 100
# name
# leehojun
# age
# 10
# --------
# args: (100, True, 'leehojun')
# 100
# True
# leehojun
# kwargs: {'score': 100, 'name': 'leehojun', 'age': '10'}
# score
# 100
# name
# leehojun
# age
# 10

# %%
# 가변 길이 위치 인수와 키워드 인수의 조합

# 가변 길이 위치 인수와 키워드 인수 조합
def func(x, *args, **kwargs):
    print(x)
    print(args)
    print(kwargs)


print("---첫 번째 인수만 지정한 결과---")
func(1)

print("---길이가 변하는 인수를 지정한 결과---")
func(1, 100, 200, 300, a="X", b="Y", c="Z")
# Out:
# ---첫 번째 인수만 지정한 결과---
# 1
# ()
# {}
# ---길이가 변하는 인수를 지정한 결과---
# 1
# (100, 200, 300)
# {'a': 'X', 'b': 'Y', 'c': 'Z'}

# %%
# A손님이 구매한 모든 상품들을 0.25%의 할인율을 적용하여 총액 계산해보기

def 가격계산(할인율, *구매가_목록) :
  '''구매가 목록을 합산하고 할인율을 반영해서 가격을 계산'''
  return (1-할인율) * sum(구매가_목록)

가격계산(0.25, 10000)  # 구매한 물건이 하나일 때
# Out:
# 7500.0

# %%
가격계산(0.25, 10000, 150000, 25000)  # 구매할 물건이 계속 늘어날 때

# 이처럼 인자가 계속 늘어날 수 있는 상황에서 사용하면 좋음
# Out:
# 138750.0

# %% [markdown]
# # 기타 *의 활용법

# %%
# 기타 *의 활용법

one, two, *three = 1,2,3,4,5
print(one, two, three) #three = 리스트

# %% [markdown]
# # 언패킹

# %%
# 자료형 리스트
a_1 = [1,2,3]
print(*a_1)
# Out:
# 1 2 3

# %%
# 튜플도 언패킹
a_2 = (1,2,3)
print(*a_2)
# Out:
# 1 2 3

# %%
# 시퀀스 언패킹 1 - 리스트 튜플
# 함수 호출 시 위치인수 지정하기 - 함수 사용 시 적용할 수 있음

def func(x, y, z) :
  print(x, y, z)
  return x + y + z

# 언패킹 하는 함수 x, y, z
param = [1, 2, 3]
w = func(*param)  # 변수에 별을 붙이면 패킹이 풀리게 된다.
print(w)
# Out:
# 1 2 3
# 6

# %%
w = func(*[1, 2, 3])
print(w)
# Out:
# 1 2 3
# 6

# %%
# 키워드 인수 데이터를 받아올때

def func(x,y,z):
  print(x,y,z)
  return x + y + z

params = {"x" : 1, "y" : 2, "z" : 3}  # 딕셔너리
w = func(**params)
print(w)
# Out:
# 1 2 3
# 6

# %%
# 언패킹 
data_to_string(*date)
# Out:
# '2023년5월8일'

# %%
data_to_string(*[2023,5,8])
# Out:
# '2023년5월8일'

# %%
data_to_string(2023, *(5,8))
# Out:
# '2023년5월8일'

# %%
# **사용 언패킹 날짜 예제

date = {'y' : 1917, 'm' :9, 'd' : 4}

data_to_string(date['y'], date['m'], date['d'])
# Out:
# '1917년9월4일'

# %%
# 언패킹 함수

data_to_string(**date)
# Out:
# '1917년9월4일'

# %% [markdown]
# # 연습문제

# %%
# 연습문제 1.

def counter(*args):
  count = len(args)
  return count

print(counter(["test","hello","python"]))

# 1. 1개
# 2. 2개
# 3. 3개
# 4. 4개
# 5. 5개
# Out:
# 1

# %%
def counter(args):
  count = len(["test","hello","python"])
  return count

print(counter(["test","hello","python"]))

# 1. 1개
# 2. 2개
# 3. 3개
# 4. 4개
# 5. 5개
# Out:
# 3

# %%
# 날짜변수 다루기 예제

def data_to_string(y,m,d):
  """연도, 월, 일을 입력받아서 yyyy년, m월 d일로 반환한다."""
  return str(y) + "년" + str(m) + "월" + str(d) + "일"

# 기본 함수값 불러오기

date = (2023,5,8)
data_to_string(date[0], date[1], date[2])
# Out:
# '2023년5월8일'

# %% [markdown]
# # 함수

# %%
# 함수를 변수로 다루기

def add_num(x, y):
  return x + y

# 변수에 대입할 수 있음
x = add_num

# 함수를 실행
z = x(100, 200)
print(z)

# %%
# 어떤 함수가 몇번 호출되었는지 확인 실행할때!!

def outer_function():
  """ 외부 함수 """

  def inner_function():
    """내부 함수"""
    count = 0
    count += 1   
    print(f"실행횟수가 {count}회 실행되었습니다.")

  return inner_function

func1 = outer_function()

# 함수 실행
func1()
func1()
func1()
# Out:
# 실행횟수가 1회 실행되었습니다.
# 실행횟수가 1회 실행되었습니다.
# 실행횟수가 1회 실행되었습니다.

# %%
# 어떤 함수가 몇번 호출되었는지 확인 실행할때!!

def outer_function():
  """ 외부 함수 """
  count = 0
  def inner_function():
    """내부 함수"""
    nonlocal count # 이 nonlocal 함수는 저장이 가능한 함수 count값을 저장 
    count += 1   
    print(f"실행횟수가 {count}회 실행되었습니다.")

  return inner_function

func1 = outer_function()

# 함수 실행
func1()
func1()
func1()
# Out:
# 실행횟수가 1회 실행되었습니다.
# 실행횟수가 2회 실행되었습니다.
# 실행횟수가 3회 실행되었습니다.

# %% [markdown]
# # lambda
#
# * lambda()는 익명함수, 이름이 없는 함수

# %%
# 람다식 람다함수
lambda 매개변수 : 결과

# %%
hojun = print
hojun('hello world')

# print를 hojun으로 받고, print함수를 호출할 수 있다.
# 즉, 이름이 있는 것은 변수로 지정할 수 있다.
# Out:
# hello world

# %%
def add(x, y):
    return x + y
def sub():
    pass
def div():
    pass
def mul():
    pass
caculator = [add, sub, div, mul]
print(caculator[0](10, 20)) # 0번째 값은 add 입니다.
# Out:
# 30

# %% [markdown]
# 우선 add, sub, div, mul이라는 사칙연산을 수행하는 함수를 선언해주었습니다. 그 다음 각 함수들의 이름을 calculator라는 배열에 넣어주었고, print로 0번째 배열을 호출하였더니 함수 add의 결과값인 30이 나오게 되었습니다.
#
# 우리가 일반적으로 사용할 수 있는 변수의 위치에 ( )(괄호)만 사용하지 않는다면 변수처럼 사용할 수 있으며, 호출할 때는 '( )'(괄호)를 사용해줍니다.

# %% [markdown]
# # lambda 예제

# %%
# 예제 1
# x라는 매개변수가 들어오면 x ** 2 를 해서 return

# 변수를 사용할 때
제곱 = lambda x : x ** 2
제곱(3)
# Out:
# 9

# %%
# 변수를 사용하지 않고 바로 실행도 가능
(lambda x : x ** 2)(3)
# Out:
# 9

# %%
# 예제 2

def f(x, y):
  return x + y

print(f(1, 4))
# Out:
# 5

# %%
# 위의 함수식을 lambda식으로 바꾸면

# 1번
f = lambda x, y : x + y
f(1, 4)

# 2번
(lambda x, y : x + y)(1, 4)
# Out:
# 5

# %%
# 람다식에서 인자를 부족하게 넣으면 에러 발생
f = lambda x, y : x + y
f(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-466bcbdec85a> in <cell line: 3>()
#       1 # 람다식에서 인자를 부족하게 넣으면 에러 발생
#       2 f = lambda x, y : x + y
# ----> 3 f(1)
#
# TypeError: <lambda>() missing 1 required positional argument: 'y'

# %% [markdown]
# # lambda 문자열

# %%
# 문자열도 가능
func = lambda x : '*' + str(x) + '*'
print(func('가나다'))
# Out:
# *가나다*

# %%
func = lambda x : str(x) * 3
print(func('가나다'))
# Out:
# 가나다가나다가나다

# %% [markdown]
# # Map 함수
#
# lambda 함수와 가장 많이 조합되어 이용하는 함수입니다. 간단히 설명드리도록 할게요.
#
# 방금 위에서 만들었던 매개변수를 제곱하여 return하는 함수를 만들어 볼겁니다. 그런데 아까 위에서 작성했던 예제는 하나의 값만 받고 하나의 값만 리턴할 수 있었죠?
#
# 여러값이 들어오게 된다면 어떻게 해야할까요?

# %%
# 첫 번째 방법
def 제곱(x):
    return x ** 2
list(map(제곱, [1, 2, 3, 4]))  # [1, 2, 3, 4]처럼 여러 개의 값을 받아올 때는 Map을 사용하면 편함

# 두 번째 방법
list(map(lambda x : x ** 2, [1, 2, 3, 4]))
# Out:
# [1, 4, 9, 16]

# %%
# 다른 예시


ex = [1,2,3,4,5]
f = lambda x : x ** 2

print(list(map(f, ex)))
# Out:
# [1, 4, 9, 16, 25]

# %%
# 위 코드에서는 먼저 ex라는 리스트를 먼저 만들고, 입력된 값을 제곱하는 람다함수 f를 생성하였습니다.
# 결국 Map은 mapping을 생각해보면 편한데, map(함수 이름, 리스트 데이터)라는 형태에 맞춰 함수 F에 ex의 요소를 매핑하라라는 뜻이다.

# %% [markdown]
# # 제너레이터 사용

# %%
# 1.1 제너레이터 사용

# 파이썬 3.x 버전부터는 반드시 list(map(f, ex)) 리스트를 꼭 붙여야 리스트 형태로 자료 붙여지게되요
# map(f, ex) -> list(map(f, ex))
# 제너레이터 장점은 시퀀스 자료형의 데이터를 처리할때 실행 시점의 값을 생성해서 효율적으로 메모리를 관리할 수 있게 합니다.

# 100G / 200G
# 4G / 8G

# %%
# 리스트가 없으면?

ex = [1,2,3,4,5]
f = lambda x : x**2
for value in map(f,ex):
  print(value)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
# 무언가의 값을 추가하기 위해서는 append
new_list = []
ex = [1,2,3,4,5]
f = lambda x : x**2
for value in map(f,ex):
  new_list.append(value)

# %%
new_list
# Out:
# [1, 4, 9, 16, 25]

# %%
ex = [1,2,3,4,5]
f = lambda x : x ** 2

print(list(map(f, ex)))
# Out:
# [1, 4, 9, 16, 25]

# %%
# 리스트 컴프리 핸션

ex = [1,2,3,4,5]
[x ** 2 for x in ex]
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# # filter 기능

# %%
# lambda함수의 filter 기능
# 조건문

list(filter(lambda x : x > 50, range(100)))

# %% [markdown]
# # reduce 함수
#
# * reduce함수는 map함수와 용법은 다르고, 형제같은 함수가 reduce 함수를 모두 적용한 다음에, 모든 값을 통합하는 함수입니다.

# %%
from functools import reduce

print(reduce(lambda x, y : x + y, [1,2,3,4,5])

#1번째 계산
#x = 1 y = 2 결과 3

#2번째 계산
#x = 3 y = 3 결과 6

#3번째 계산
#x = 6 y = 4 결과 10

#4번째 계산
#x = 10 y = 5 결과 15
# Out:
# 15

# %%
x = 0
for y in [1,2,3,4,5]:
  x += y

print(x)
# Out:
# 15

# %% [markdown]
# # 예제

# %% [markdown]
# ## 1. 은행에서 적금통장을 개설하고 입금/출금/잔액확인을 할 때

# %%
# 전산개발 요구서
# 데이터를 어디서 받아와야하는지
# 1) 현재 우리가 가지고 있는 데이터는 무엇인지?
# 2) 만들 수 있는 데이터나 가공할 수 있는 데이터가 추가로 있는지?
# 3) 아예 가져올 수 있는지?

# %%
# 1. 은행계좌 만들기

def open_account():
  print('새로운 계좌를 개설합니다.')

open_account()
# Out:
# 새로운 계좌를 개설합니다.

# %%
# 2. 입금하기

def deposit(money, balance):  # money = 입금 받은 돈 / balance = 잔액
  print(f'{money}원이 입금되었습니다. 잔액은 {money + balance}원입니다.')
  return money + balance

balance = 0
balance = deposit(5000, balance)
# Out:
# 5000원이 입금되었습니다. 잔액은 5000원입니다.

# %%
# 3. 출금하기

def withdraw(balance, money) :
  if balance >= money :
    print(f'{money}원을 출금했습니다. 잔액은 {balance - money}원입니다.')
    return balance - money
  else :
    print(f'잔액이 부족합니다. 출금 가능한 잔액은 {balance}원입니다.')

balance = withdraw(balance, 3000)
# Out:
# 3000원을 출금했습니다. 잔액은 2000원입니다.

# %%
# 4. 수수료 부과하기

def withdraw_other(balance, money) :

  commission = 500
  print(f'업무 시간 외에는 수수료가 부과됩니다. {money}원을 출금하여 수수료 {commission}원이 발생합니다. 잔액은 {balance - money - commission}원입니다.')
  return balance - money - commission

withdraw_other(balance, 1000)
# Out:
# 업무 시간 외에는 수수료가 부과됩니다. 1000원을 출금하여 수수료 500원이 발생합니다. 잔액은 500원입니다.
# 500

# %% [markdown]
# # 연습문제
#
# 철수가 은행에 취업을 해서 처음 업무지시를 받은건 새로운 적금상품에 추가로 돈을 입금할 경우 자동으로 원금과 이자가 더해지도록 로직을 구현해야하는 상황
#
# 조건
# 1. 함수를 사용하여 기능 구현
# 2. 모두 구현 된 경우 '입금이 완료되었습니다' 메세지
# 3. 적금 금리는 3.0& / 이자 산식은 원금 * 금리

# %%
# x - 원래 있었던 금액
# y - 새로 불입한 금액
# z - 이자

def service_sum_amount(x, y, z):
  if y > 0 :
    return int(x + y + (y * z/100))

print(service_sum_amount(0, 5000, 3.0))
# Out:
# 5150

# %% [markdown]
# # 가볍게 읽어보기

# %%
def service_price():
  service = input('서비스의 종류를 입력하세요 기본/프리미엄/올인원')
  valueprice = input('부가세 포함여부? y/n')
  if valueprice == 'y':
    if service == '기본':
      result = 300000 * 1.1
    elif service == '프리미엄':
      result = 600000 * 1.1
    elif service == '올인원':
      result = 1000000 * 1.1
  else:
    print("비용이 발생되지 않았습니다.")
  print(f"{result}만원 입니다.")
  #print(f"{round(result,1)}만원입니다.)

# %%
##########################################
# 스페이스 어드벤처 게임
# 벤 & 쉬무엘 만듦
##########################################
 
# 플레이어 환영 메시지
def doWelcome():
    # 텍스트 출력하기
    print("탐험가 여러분을 환영합니다!")
    print("혼란스러운 상태에서 잠을 깬 여러분은 아무것도 떠오르지 않습니다.")
    print("방문까지 겨우 기어가 손잡이를 돌렸더니 문이 열립니다.")
    print("밖으로 나가 봐도 모든 것이 낯설기만 합니다.")
    print("바깥 풍경은 척박하고 황량한 붉은 흙만이 흩날릴 뿐입니다.")
    print("우주복을 입은 자신을 발견하곤 모든 것이 궁금해집니다.")
 
# 장소: 출발점
def doStart():
    # 텍스트 출력하기
    print("주위를 둘러봐도 붉은 사막과 바위 더미와 먼지뿐입니다.")
    print("여러분 앞에는 이상하게 생긴 팔각형 구조물이 있습니다.")
    print("가까이 가니 삐 소리가 들립니다. 그리곤 멈춥니다. 아니, 계속됩니다.")
    # 플레이어 행동 선택 프롬프트
    choice = " "
    while not choice in "PSBR":
        print("여러분이 할 수 있는 일:")
        print("P = 바위 더미를 조사한다")
        print("S = 구조물에 접근한다")
        print("B = 삐 소리가 나는 곳으로 간다")
        print("R = 도망간다!")
        choice = input("무엇을 하고 싶으세요? [P/S/B/R]").strip().upper()
    # 행동 실행하기
    if choice == 'P':
        doBoulders()
    elif choice == 'S':
        doStructure()
    elif choice == 'B':
        doBeeping()
    elif choice == 'R':
        doRun()

# 장소: 바위 더미
# 인벤토리 시스템 구현용 개발자 메모 
# 이곳이 열쇠가 숨겨진 장소가 됩니다.
def doBoulders():
    # 텍스트 출력하기
    print("정말인가요? 그건 바위 더미입니다.")
    print("크고 무겁고 단순한 바위입니다.")
    # 시작 위치로 돌아가기
    doStart()

# 장소: 구조물
def doStructure():
    # 텍스트 출력하기
    print("여러분은 이상한 구조물을 조사합니다.")
    print("안에서는 오싹하면서도 기이한 소리가 들립니다.")
    print("문도 없고 창문도 없습니다.")
    print("아니, 문처럼 보여서 한번 열어 보려고 합니다.")
    print("그리고 삐 소리가 들립니다. 어디서 나는 소리일까요?")
    # 플레이어 행동 선택 프롬프트
    choice = " "
    while not choice in "SDBR":
        print("여러분이 할 수 있는 일:")
        print("S = 시작 지점으로 돌아간다")
        print("D = 문을 연다")
        print("B = 삐 소리가 나는 곳으로 간다")
        print("R = 도망간다!")
        choice = input("무엇을 하고 싶으세요? [S/D/B/R]").strip().upper()
    # 행동 실행하기
    if choice == 'S':
        doStart()
    elif choice == 'D':
        doStructureDoor()
    elif choice == 'B':
        doBeeping()
    elif choice == 'R':
        doRun()
 
# 장소: 구조물 입구
# 인벤토리 시스템 구현용 개발자 메모 
# 열쇠가 있을 때만 열 수 있습니다.
def doStructureDoor():
    # 텍스트 출력하기
    print("문은 잠긴 듯합니다.")
    print("둥근 구멍이 보입니다. 열쇠 구멍일까요?")
    print("그쪽으로 손을 내밀지만 파란빛이 번쩍이며 닫혀 버립니다!")
    print("계획한 대로는 잘 안 되는군요.")
    # 플레이어 행동 선택 프롬프트
    choice = " "
    while not choice in "SR":
        print("여러분이 할 수 있는 일:")
        print("S = 구조물로 돌아간다")
        print("R = 도망간다!")
        choice = input("무엇을 하고 싶으세요? [S/R]").strip().upper()
    # 행동 실행하기
    if choice == 'S':
        doStructure()
    elif choice == 'R':
        doRun()
 
# 장소: 삐 소리 탐색하기
def doBeeping():
    pass
 
# 플레이어가 도망가기를 선택하기
def doRun():
    # 텍스트 출력하기
    print("한동안 달립니다.")
    print("그리곤 허공에 뜬 자신을 발견합니다. 아래로, 아래로, 아래로.")
    print("아주 깊은 골짜기로 떨어지며 다시는 빛을 보지 못하리라는 생각이 듭니다.")
    print("그리 용감한 행동은 아니었네요. 그렇죠?")
    # 사망, 게임 끝내기
    gameOver()

# 게임 끝내기
def gameOver():
    print("게임 오버!")
 
# 실제 게임 시작은 이곳에서
# 환영 메시지 출력하기
doWelcome()
# 게임 시작하기
doStart()
