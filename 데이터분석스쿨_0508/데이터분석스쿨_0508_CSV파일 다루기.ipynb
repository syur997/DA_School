# %% [markdown]
# # 파일
#
# * 파일은 컴퓨터를 실행할 때 가장 기본이 되는 단위
# * 보통 프로그램 실행할 때 파일을 실행한다.
# * 그 중의 우리는 CSV, Excel, txt, .py 파일

# %%
# 1. 파일 읽기 예제

#f = open("파일명" , "파일 열기 모드")
#f.close()

# 파일 여는 모드는 읽기, 쓰기, 추가 등등이 있음
# 읽기모드 -> r / 쓰기 w / 추가 a

f = open('song.txt', 'w')
# Out:
# 554

# %%
f.write(
    '''
    오랫동안 내 마음엔
구름 가득 비가 내려
따스한 햇살 비추길
간절히 바랬죠
어깨를 적신 빗방울도
마르면 나만 홀로
남겨질까 너무나도 두려웠죠
그댄 빛처럼 비 갠 뒤처럼
내 마음에 떠오르죠 이렇게
Cause you are
내게 내린 빛과
You are 너무 고운 꿈과
일곱 빛으로 온 세상을
더 아름답게 물들여
언제나 Yeah U R
텅 빈 푸른 언덕 위에
무지개는 지붕이 돼
그 아래 가만히 누워
하늘을 보아요
세상 가장 평온함과
처음 느낀 설렘
누구보다 사랑스러워
고갤 돌리면 그대 미소에
나도 몰래 손을 뻗죠 이렇게
Cause you are
내게 내린 빛과
You are 너무 고운 꿈과
일곱 빛으로 온 세상을
더 아름답게 물들여
언제나 Yeah U R
내 창을 적신 비가 그치면
Under the Rainbow
그대 기다리겠죠
차마 난 하지 못했던
얘기 못했던 그 모든 비밀
오늘은 전하고 싶어
You are 항상 나의 곁에
You are 여린 내 맘 속에
더 눈부시게 아름답게
온 밤하늘을 채우는
You're my star
Yeah U R
Oh U R U R Oh U R 
'''
)

# %%
f.close()

# %%
f = open('song.txt', 'r')
contents = f.read()
print(contents)
f.close()

# 1행에서 open()함수 다음에 파일명 다음에 읽기 모드 r을 입력해서 파일에 대한 값을 f에 저장
# 2행에서 f를 이용해서 Read()함수를 실행하면 해당 파일의 텍스트들이 contents에 할당이 되고
print()
# Out:
#     오랫동안 내 마음엔
# 구름 가득 비가 내려
# 따스한 햇살 비추길
# 간절히 바랬죠
# 어깨를 적신 빗방울도
# 마르면 나만 홀로
# 남겨질까 너무나도 두려웠죠
# 그댄 빛처럼 비 갠 뒤처럼
# 내 마음에 떠오르죠 이렇게
# Cause you are
# 내게 내린 빛과
# You are 너무 고운 꿈과
# 일곱 빛으로 온 세상을
# 더 아름답게 물들여
# 언제나 Yeah U R
# 텅 빈 푸른 언덕 위에
# 무지개는 지붕이 돼
# 그 아래 가만히 누워
# 하늘을 보아요
# 세상 가장 평온함과
# 처음 느낀 설렘
# 누구보다 사랑스러워
# 고갤 돌리면 그대 미소에
# 나도 몰래 손을 뻗죠 이렇게
# Cause you are
# 내게 내린 빛과
# You are 너무 고운 꿈과
# 일곱 빛으로 온 세상을
# 더 아름답게 물들여
# 언제나 Yeah U R
# 내 창을 적신 비가 그치면
# Under the Rainbow
# 그대 기다리겠죠
# 차마 난 하지 못했던
# 얘기 못했던 그 모든 비밀
# 오늘은 전하고 싶어
# You are 항상 나의 곁에
# You are 여린 내 맘 속에
# 더 눈부시게 아름답게
# 온 밤하늘을 채우는
# You're my star
# Yeah U R
# Oh U R U R Oh U R

# %%
# with문

# with을 활용해서 Open()함수를 대체할 수 있다.
## with문은 들여쓰기를 잘해야한다. 함수 if
# 결론적으로 close()문을 안쓰는 편리함이 있고,

with open('song.txt', 'r') as my_song_list:
  content = my_song_list.read()
  print(content)
# Out:
#     오랫동안 내 마음엔
# 구름 가득 비가 내려
# 따스한 햇살 비추길
# 간절히 바랬죠
# 어깨를 적신 빗방울도
# 마르면 나만 홀로
# 남겨질까 너무나도 두려웠죠
# 그댄 빛처럼 비 갠 뒤처럼
# 내 마음에 떠오르죠 이렇게
# Cause you are
# 내게 내린 빛과
# You are 너무 고운 꿈과
# 일곱 빛으로 온 세상을
# 더 아름답게 물들여
# 언제나 Yeah U R
# 텅 빈 푸른 언덕 위에
# 무지개는 지붕이 돼
# 그 아래 가만히 누워
# 하늘을 보아요
# 세상 가장 평온함과
# 처음 느낀 설렘
# 누구보다 사랑스러워
# 고갤 돌리면 그대 미소에
# 나도 몰래 손을 뻗죠 이렇게
# Cause you are
# 내게 내린 빛과
# You are 너무 고운 꿈과
# 일곱 빛으로 온 세상을
# 더 아름답게 물들여
# 언제나 Yeah U R
# 내 창을 적신 비가 그치면
# Under the Rainbow
# 그대 기다리겠죠
# 차마 난 하지 못했던
# 얘기 못했던 그 모든 비밀
# 오늘은 전하고 싶어
# You are 항상 나의 곁에
# You are 여린 내 맘 속에
# 더 눈부시게 아름답게
# 온 밤하늘을 채우는
# You're my star
# Yeah U R
# Oh U R U R Oh U R

# %%
# 한줄로 읽어오는 방법
# 파일 전체의 텍스트를 문자열로 반환하는 read()대신에 readlines()함수를 사용하면 
# 한줄의 기준은 \n

with open('song.txt', 'r') as my_song_list:
  content_list = my_song_list.readlines()
  print(content_list)
# Out:
# ['\n', '    오랫동안 내 마음엔\n', '구름 가득 비가 내려\n', '따스한 햇살 비추길\n', '간절히 바랬죠\n', '어깨를 적신 빗방울도\n', '마르면 나만 홀로\n', '남겨질까 너무나도 두려웠죠\n', '그댄 빛처럼 비 갠 뒤처럼\n', '내 마음에 떠오르죠 이렇게\n', 'Cause you are\n', '내게 내린 빛과\n', 'You are 너무 고운 꿈과\n', '일곱 빛으로 온 세상을\n', '더 아름답게 물들여\n', '언제나 Yeah U R\n', '텅 빈 푸른 언덕 위에\n', '무지개는 지붕이 돼\n', '그 아래 가만히 누워\n', '하늘을 보아요\n', '세상 가장 평온함과\n', '처음 느낀 설렘\n', '누구보다 사랑스러워\n', '고갤 돌리면 그대 미소에\n', '나도 몰래 손을 뻗죠 이렇게\n', 'Cause you are\n', '내게 내린 빛과\n', 'You are 너무 고운 꿈과\n', '일곱 빛으로 온 세상을\n', '더 아름답게 물들여\n', '언제나 Yeah U R\n', '내 창을 적신 비가 그치면\n', 'Under the Rainbow\n', '그대 기다리겠죠\n', '차마 난 하지 못했던\n', '얘기 못했던 그 모든 비밀\n', '오늘은 전하고 싶어\n', 'You are 항상 나의 곁에\n', 'You are 여린 내 맘 속에\n', '더 눈부시게 아름답게\n', '온 밤하늘을 채우는\n', "You're my star\n", 'Yeah U R\n', 'Oh U R U R Oh U R \n']

# %%
content_list[2]
# Out:
# '구름 가득 비가 내려\n'

# %%
with open('song.txt', 'r') as my_song_list:
  i = 0
  while True:
    line = my_song_list.readline()
    if not line:
      break
    print(line.replace("\n", ""))
    i = i + 1
# Out:
#     오랫동안 내 마음엔
# 구름 가득 비가 내려
# 따스한 햇살 비추길
# 간절히 바랬죠
# 어깨를 적신 빗방울도
# 마르면 나만 홀로
# 남겨질까 너무나도 두려웠죠
# 그댄 빛처럼 비 갠 뒤처럼
# 내 마음에 떠오르죠 이렇게
# Cause you are
# 내게 내린 빛과
# You are 너무 고운 꿈과
# 일곱 빛으로 온 세상을
# 더 아름답게 물들여
# 언제나 Yeah U R
# 텅 빈 푸른 언덕 위에
# 무지개는 지붕이 돼
# 그 아래 가만히 누워
# 하늘을 보아요
# 세상 가장 평온함과
# 처음 느낀 설렘
# 누구보다 사랑스러워
# 고갤 돌리면 그대 미소에
# 나도 몰래 손을 뻗죠 이렇게
# Cause you are
# 내게 내린 빛과
# You are 너무 고운 꿈과
# 일곱 빛으로 온 세상을
# 더 아름답게 물들여
# 언제나 Yeah U R
# 내 창을 적신 비가 그치면
# Under the Rainbow
# 그대 기다리겠죠
# 차마 난 하지 못했던
# 얘기 못했던 그 모든 비밀
# 오늘은 전하고 싶어
# You are 항상 나의 곁에
# You are 여린 내 맘 속에
# 더 눈부시게 아름답게
# 온 밤하늘을 채우는
# You're my star
# Yeah U R
# Oh U R U R Oh U R

# %%
song_list_new = []

with open('song.txt', 'r') as my_song_list:
  i = 0
  while True:
    line = my_song_list.readline()
    if not line:
      break
    song_list_new.append(line.replace("\n", ""))
    i = i + 1

# %%
song_list_new
# Out:
# ['',
#  '    오랫동안 내 마음엔',
#  '구름 가득 비가 내려',
#  '따스한 햇살 비추길',
#  '간절히 바랬죠',
#  '어깨를 적신 빗방울도',
#  '마르면 나만 홀로',
#  '남겨질까 너무나도 두려웠죠',
#  '그댄 빛처럼 비 갠 뒤처럼',
#  '내 마음에 떠오르죠 이렇게',
#  'Cause you are',
#  '내게 내린 빛과',
#  'You are 너무 고운 꿈과',
#  '일곱 빛으로 온 세상을',
#  '더 아름답게 물들여',
#  '언제나 Yeah U R',
#  '텅 빈 푸른 언덕 위에',
#  '무지개는 지붕이 돼',
#  '그 아래 가만히 누워',
#  '하늘을 보아요',
#  '세상 가장 평온함과',
#  '처음 느낀 설렘',
#  '누구보다 사랑스러워',
#  '고갤 돌리면 그대 미소에',
#  '나도 몰래 손을 뻗죠 이렇게',
#  'Cause you are',
#  '내게 내린 빛과',
#  'You are 너무 고운 꿈과',
#  '일곱 빛으로 온 세상을',
#  '더 아름답게 물들여',
#  '언제나 Yeah U R',
#  '내 창을 적신 비가 그치면',
#  'Under the Rainbow',
#  '그대 기다리겠죠',
#  '차마 난 하지 못했던',
#  '얘기 못했던 그 모든 비밀',
#  '오늘은 전하고 싶어',
#  'You are 항상 나의 곁에',
#  'You are 여린 내 맘 속에',
#  '더 눈부시게 아름답게',
#  '온 밤하늘을 채우는',
#  "You're my star",
#  'Yeah U R',
#  'Oh U R U R Oh U R ']

# %%
with open('song.txt','r') as my_song_list:
  contents = my_song_list.read()
  word_list = contents.split(" ")
  line_list = contents.split("\n")

print(f"총 글자수는 {len(contents)}입니다.")
print(f"총 단어수는 {len(word_list)}입니다.")
print(f"총 줄수는 {len(line_list)}입니다.")
# Out:
# 총 글자수는 554입니다.
# 총 단어수는 121입니다.
# 총 줄수는 45입니다.

# %%
### 파일쓰기

# 앞서 파일쓰기 중에서 인코딩 utf-8 / cp949 / euc-kr 

# 인코딩 실습

f = open("count_list.txt", 'w', encoding = 'utf8')

# %%
for i in range(1, 11):
  data = f'{i}번째입니다.'
  f.write(data)
f.close()

# %%
with open('count_list_new.txt', 'w', encoding = 'utf8') as f:
  for i in range(1,11):
    data = f'{i}번째입니다.'
    f.write(data)

# %%
# Pickle 모듈

# 파이썬 프로그램을 실행할때마다 변수 객체를 메모리에 저장하고, 
# 컴퓨터를 껐다가 켜면 모두 날라가죠

# 파이썬은 pickle모듈을 제공합니다.

# 메모리에 로딩된 객체들을 연속적으로 사용할 수 있게 

# 예를 들어 데이터, 클래스, 함수, 프로그램 

# 향후 대기업, 관련 빅데이터 플랫폼 활용

# %%
# pickle 모듈을 사용하려면 import, 저장하고자하는 객체를 넘기면 된다.
# 파일 열 때 r / 파일 쓸 때 w
# pickle에서는 파일을 열 때 rb / 파일을 쓸 때 wb

# %%
import pickle

f = open('list.pickle', 'wb')
test=[1, 2, 3, 4, 5]
pickle.dump(test, f)  # dump는 test를 f에 넣어줌
f.close()

# %%
f = open('list.pickle', 'rb')  
test_pickle = pickle.load(f) # pickle를 읽어오려면 꼭 load를 사용해야함
print(test_pickle)
# Out:
# [1, 2, 3, 4, 5]

# %%
# load를 사용하지 않고 그냥 f 썼을 때
f
# Out:
# <_io.BufferedReader name='list.pickle'>

# %%
# pickle은 클래스도 저장가능하다.

class Multiply(object):
  def __init__(self, multi):
    self.multi = multi
  def multiply(self, number):
    return number * self.multi

multi_test = Multiply(5)
multi_test.multiply(10)
# Out:
# 50

# %%
f = open('multiply_object.pickle', 'wb')
pickle.dump(multi_test, f)

# %%
f = open('multiply_object.pickle', 'rb')
multi_test = pickle.load(f)

# %%
multi_test.multiply(10)
# Out:
# 50

# %% [markdown]
# # csv 데이터
#
# * 데이터 분석의 대부분은 통계프로그램이 아니라 엑셀 작업을 주로 해요
# * 그만큼 우리는 스트레드시트 데이터를 많이보게되고
# * Excel 잘 다뤄도 -> 데이터분석 잘한다.

# %% [markdown]
# * CSV 쉼표로 나누진 데이터인데
# * 1,2,3,4,5 -> test.csv / txt
# * .xlsx -> .csv
# * 읽기에도 좋고, 용량도 excel파일보다 작고, 콤마로 구분되어서 사용하기 편하거나 전처리하기 좋다.
# * Python -> excel -> python

# %%
import csv
import os #경로 지정

# %%
# 경로 지정

os.chdir('/content/sample_data')

# %%
f = open('song_new.txt', 'w')
f.write('''
이윽고 내가 한눈에 너를 알아봤을 때
모든 건 분명 달라지고 있었어
내 세상은 널 알기 전과 후로 나뉘어
니가 숨 쉬면 따스한 바람이 불어와
니가 웃으면 눈부신 햇살이 비춰
거기 있어줘서 그게 너라서
가끔 내 어깨에 가만히 기대주어서
나는 있잖아 정말 빈틈없이 행복해
너를 따라서 시간은 흐르고 멈춰
물끄러미 너를 들여다 보곤 해
그것 말고는 아무것도 할 수 없어서
너의 모든 순간 그게 나였으면 좋겠다
생각만 해도 가슴이 차올라 나는 온통 너로
보고 있으면 왠지 꿈처럼 아득한 것
몇 광년 동안 날 향해 날아온 별빛 또 지금의 너
*거기 있어줘서 그게 너라서
가끔 나에게 조용하게 안겨주어서
나는 있잖아 정말 남김없이 고마워
너를 따라서 시간은 흐르고 멈춰
물끄러미 너를 들여다보곤 해
너를 보는 게 나에게는 사랑이니까
너의 모든 순간 그게 나였으면 좋겠다...
''')
f.close()

# %%
# open

f = open('test.csv', 'r', encoding = '')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-db7d2ffe02a5> in <cell line: 3>()
#       1 # open
#       2
# ----> 3 f = open('test.csv', 'r', encoding = '')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.csv'

# %%
new = csv.reader(f)
new

# %%
print(new)

# %%
# csv파일 출력하기

a_list = []
for i in new:
  # if i != '' :
  if i != '':
    print(i)
    a_list.append(i)

# %%
# 함수화 하기

def opencsv(filename):
  f = open(filename, 'r')
  reader = csv.reader(f)
  output = []
  for i in reader:
    output.append(i)
  return output

# %%
opencsv('test.csv')

# %%
# 새로운 데이터 읽기 예제

a = [['구', '전체', '내국인', '외국인'], 
     ['관악구','519864','502089','17775'], 
     ['강남구','547602','542498','5104'], 
     ['송파구','686181', '679247', '6934'], 
     ['강동구','428547','424235','4312']]

# %%
a
# Out:
# [['구', '전체', '내국인', '외국인'],
#  ['관악구', '519864', '502089', '17775'],
#  ['강남구', '547602', '542498', '5104'],
#  ['송파구', '686181', '679247', '6934'],
#  ['강동구', '428547', '424235', '4312']]

# %%
f = open('abc.csv', 'w', newline = '')

# %%
new_csv = csv.writer(f, delimiter = ',')

# %%
new_csv.writerows(a) #a자료를 csv파일에 넣기
f.close()

# %%
# 새로운 데이터 쓰기 예제

b = [['구', '전체', '내국인', '외국인'], 
     ['관악구','519864','502089','17775'], 
     ['강남구','547602','542498','5104'], 
     ['송파구','686181', '679247', '6934'], 
     ['강동구','428547','424235','4312']]

# %%
# 함수화 하기

def writecsv(filename, list):
  with open(filename, 'w', newline = '') as f:
    a = csv.writer(f, delimiter = ',')
    a.writerows(list)

# %%
writecsv('new_abc.csv', b)
