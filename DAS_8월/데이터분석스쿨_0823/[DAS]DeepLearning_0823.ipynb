# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),  # input data
    Dense(128, activation='relu'),  # 은닉층(hidden layer)
    Dense(10, activation='softmax')  # output data
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2578 - accuracy: 0.9260 - val_loss: 0.1551 - val_accuracy: 0.9551
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1118 - accuracy: 0.9666 - val_loss: 0.0984 - val_accuracy: 0.9720
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0768 - accuracy: 0.9762 - val_loss: 0.0869 - val_accuracy: 0.9743
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0572 - accuracy: 0.9827 - val_loss: 0.0763 - val_accuracy: 0.9741
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0454 - accuracy: 0.9858 - val_loss: 0.0841 - val_accuracy: 0.9747

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
plt.show()
