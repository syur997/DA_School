# %% [markdown]
# # 1. 클래스

# %% [markdown]
# ## 1-1. 왜 클래스 같은 객체지향 프로그래밍이 필요할까?

# %% [markdown]
# 객체 지향 프로그래밍은 프로그래밍을 좀 더 효율적이고 유지보수가 용이하게 하는 방법 중 하나입니다. 이 방법은 실생활에 존재하는 물건이나 개념을 객체로 정의하고, 이러한 객체들 간의 상호작용으로 프로그램을 만드는 것입니다. 이러한 방법을 사용하면 프로그램을 작게 쪼개서 개발하고, 각 객체 간의 관계를 명확히 하여 유지보수가 쉬워집니다. 또한 코드의 재사용성이 높아지고, 확장성 또한 높아집니다. 따라서 객체 지향 프로그래밍은 대규모 프로그램 개발에 적합합니다.
#
# 왜 함수를 사용할까? 유지보수의 편리성 / 협업의 편리성등을 얘기했는데 다른 사람이 만든 코드를 재사용하고 싶을때 사용하는 대표적인 방법이라고 생각하면 편리할 것 같다.
#
# 함수 처럼 어떤 기능을 함수 코드로 묶어 두는 것이 아닌 어떤 기능을 수행하는 하나의 단일 프로그램을 객체라고 하는 코드로 만들어 다른 프로그래머가 재사용 할 수 있도록 한다.
#
# 사실 객체 지향 프로그래밍은 제가 설명하기에는 고 수준의 지식이라고 생각하지만  저는 데이터 분석 스쿨에 맞게 기본적인 특성에 대해서만 다루고 여러 모로 파이썬 구현 방법에 대해서 배울 것입니다.

# %% [markdown]
# ## 2-1. 객체와 클래스에 대해 알아보면?

# %% [markdown]
# C를 제외한 모든 프로그래밍 언어는 객체지향프로그래밍 언어라고 합니다.
# 객체 지향 프로그래밍이란 객체를 우선으로 생각해서 프로그래밍한다는 의미
#
# * 결론적으로 클래스 라는 것을 기반으로 객체를 만들고,
# 그러한 객체를 우선으로 하는 프로그래밍을 해야함
#
# [객체]
#
# 데이터와 기능을 한데 모은것으로, 변수에 대입해서 다룰수 있습니다.
# 객체가 가지는 데이터를 인스턴스변수라 하고,
# 객체가 가지는 함수와 같은 기능을 메서드라고 부릅니다.
#
# * 실생활에 존재하는 물건이나 존재, 속성과 행동으로 구분
# * 속성은 변수로 정의
# * 행동은 함수로 정의
#
# 축구 게임에서
# * 객체는 선수, 팀
# * 속성은 선수의 이름, 소속팀, 포지션
# * 행동은 공을 차거나 골을 넣는것
#
# [클래스]
#
# 기본적인 데이터는 내장 객체만으로도 사용하는데 문제가 없으나, 복잡한 데이터를 다루기 시작하면서 데이터와 기능을 모으는 모아진 객체가 필요한 경우가 있습니다. 객체의 내용을 결정하는 정의가 필요하고 이 정의의 모음이 클래스라고 합니다. 클래스로 부터 객체를 만들면 객체 생성 또는 인스턴스 생성이라고 합니다.
#
# 보통 많이 표현하는게 붕어빵 기계입니다.
#
# 어느 붕어빵이 나와도 클래스 코드 같은 붕어빵 기계가 있다면 재료만 바꾸면 되는것처럼
#
# 우리도 클래스를 통해 다양한 붕어빵을 만들수 있음

# %% [markdown]
# ## 3-1. 클래스의 기초

# %% [markdown]
# ### 클래스 기초
#
# 클래스는 기본적으로 다음과 같이 사용합니다. 클래스는 다음과 같이 class를 지정하고, :을 붙인 뒤 다음 줄부터 클래스를 정의하는 구문 또는 함수등으로 채웁니다.
#
# 클래스 이름은 변수와 동일하고, 대문자로 시작합니다. 그리고 들여쓰기를 주의해야합니다.
#
# 특히 매서드의 첫번째 매개변수는 self로 지정해야합니다.

# %%
#  클래스 정의
#  클래스명은 첫 문자 대문자로 권장 !
class 클래스명() :
  클래스 정의


#  첫 변수는 꼭 self가 필수
#  변수는 1개 이상 가능
class Test(self, var1, var2) :
  print('축구 선수를 생성합니다.')
  self.name = name
  self.team = team

# %%
# 클래스 정의 - 함수 사용 가능
class Test(self, var1, var2) :
  print('축구 선수를 생성합니다.')
  self.name = name
  self.team = team
  def 메서드(self) :
    코드

# 클래스 함수 사용 예시
class Person :
  def greeting(self) :
    print('hello')

# * Person이라는 클래스를 other라는 변수에 넣을 수 있음
#   그렇다면 Person = other 같아짐
other = Person()

# * other.greeting = Person.greeting
#   hello를 출력하는 함수가 실행됨
other.greeting()

# %% [markdown]
# * **우리가 사용했던 int, float, list, dict도 class임**
#
# int 클래스에 10을 넣어서 인스턴스 a를 만들었습니다. 마찬가지로 list 클래스에 range(10)을 넣어서 인스턴스 b를 만들고, dict 클래스에 x=10, y=20을 넣어서 인스턴스 c를 만들었습니다. 잘 보면 Person으로 인스턴스를 만드는 방법과 똑같습니다.
#
# 물론 정수는 매우 자주 사용하므로 int를 생략하고 10을 바로 넣습니다. 그리고 리스트와 딕셔너리도 자주 사용하므로 축약된 문법인 [ ]과 { }를 제공하지만 클래스인 것은 같습니다.
#
# 다음과 같이 리스트를 조작할 때 메서드를 사용했었죠? 인스턴스 b에서 메서드 append를 호출해서 값을 추가합니다. 이 부분도 지금까지 메서드를 만들고 사용한 것과 같은 방식입니다.

# %%
print(int)
print(float)
print(list)
print(dict)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'list'>
# <class 'dict'>

# %%
# 빈 클래스 만들기
class Person :
  pass

# %% [markdown]
# ### 클래스와 객체는 무슨 차이가 있을까?

# %% [markdown]
# 클래스는 객체를 표현하는 문법이라고 했는데, 클래스로 인스턴스를 만든다고 하니 좀 헷갈리죠? 사실 인스턴스와 객체는 같은 것을 뜻합니다. 보통 객체만 지칭할 때는 그냥 객체(object)라고 부릅니다. 하지만 클래스와 연관지어서 말할 때는 인스턴스(instance)라고 부릅니다.
#
# 그래서 다음과 같이 리스트 변수 a, b가 있으면 a, b는 객체입니다. 그리고 a와 b는 list 클래스의 인스턴스입니다.

# %% [markdown]
# # 2. 클래스의 속성

# %%
# 메서드 안에서 메서드를 호출하기

class Person:
  def greeting(self):
    print('Hello')

  def hello(self):
    self.greeting() # self.메서드() 형식으로 클래스 안의 메서드를 호출

james = Person()
james.greeting()  # 이렇게 하면 print문이 실행되어 Hello가 나옴
james.hello()  # hello 메서드에는 print문이 없지만 self.greeting()이 있기 때문에 greeting 메서드가 실행되어 Hello가 나옴
# Out:
# Hello
# Hello

# %% [markdown]
# 메서드를 정의할때는 함수와 같이 def문을 사용합니다. 클래스를 많이 보시면 다음과 같이 __ init __ 이라는 초기화용 메서드를 입력합니다.
#
# init은 인스턴스 변수 정의 등 초기화 처리를 하게 되는데
# 메서드의 첫번째 인수에는 기본값이 자신을 가치키는 self라는 객체를 사용하고 이는 자동 반영됩니다.

# %%
# 초기화 메서드

def __init__(self, 인수1, 인수2) :
  self.인수1 = 초기값1
  self.인수2 = 초기값2

def __init__(self, name, team) :
  self.name = name
  self.team = team

# %% [markdown]
# ### _의 쓰임
# 1. 변수명이 길 때 : name_team_select
# 2. 선언하고 싶지 않은 변수에 대해서 사용(쓰이지 않을 변수에 이름을 지정하기 싫을 때)
#
#   for _ in range(10):
#
#     print('hello')
#
#
# * _를 2개 사용하면?
# 대표적으로 __ str __ __ init __()등으로 사용되는데 이는 특수한 예약함수나 변수를 뜻한다.
#
# __ str __() 함수의 경우 클래스로 인스턴스를 생성했을때, 그 인스턴스 자체를 pinrt()함수로 화면에 출력하면 나오는 값을 뜻한다.
#
# __ init __() 는 앞서 봤듯이 클래스에서 시작할때에 초기 생성하는 것으로 알아두면 좋다.

# %% [markdown]
# ## 2-1. 클래스 속성의 선언 및 예시

# %%
class BaseballPlayer():
  def __init__(self, name, position, team, team_score):
    self.name = name
    self.position = position
    self.team = team
    self.team_score = team_score
  
  def change_team(self, new_team):
    print('선수가 팀을 이적하였습니다.')
    self.team = new_team

  def __str__(self):
    return f'안녕하세요. 저는 {self.team}팀의 {self.position}, {self.name}입니다. 저희 팀 순위는 {self.team_score}위입니다.'

# %%
nosihwan = BaseballPlayer('노시환', '타자', '한화', 10)

# %%
print(nosihwan)
# Out:
# 안녕하세요. 저는 한화팀의 타자, 노시환입니다. 저희 팀 순위는 10위입니다.

# %%
# 소속팀을 변경하고 싶을 때
nosihwan.change_team('SSG')
print(nosihwan)
# Out:
# 선수가 팀을 이적하였습니다.
# 안녕하세요. 저는 SSG팀의 타자, 노시환입니다. 저희 팀 순위는 10위입니다.

# %% [markdown]
# 클래스 선언의 기본을 알았으니 이제 속성을 통해 야구선수 클래스를 구성해보도록 할텐데요. 먼저 클래스의 속성을 추가하는 선언에 대해 알아보겠습니다.
#
# __init__()이 바로 선언을 위한 예약함수인데요. 위에 배웠었죠 파이썬에서 대표적인 예약함수이고, 이러한 함수들은 약속한 형태의 작업을 수행합니다.
#
# __init__() 함수는 이 클래스에서 사용할 변수를 정의하는 함수 입니다.
#
# __init__() 함수의 첫번째 매개변수는 반드시!!!!! self 변수를 사용해야한다.
#
# self변수는 클래스에서 생성된 인스턴스에 접근하는 예약어이고,
#
#     self.name = name
#
#     self.position = position
#
#     self.team = team
#
#     self.team_score = team_score
#
# 다음과 같은 변수들이 인스턴스 변수입니다.
#
# 약간 딕셔너리와 비슷하죠? 생성된 인스턴스에 있는 각 변수들에 매개변수인 self.변수명에 값이 할당됩니다.
#
# 클래스의 변수는 self.변수이름으로 사용되는데 __init__()함수에서는 언제든 마음껏 만들수 있습니다.
#
# 물론 다른데에서도 만들수는 있지만 데이터 분석에서는 흔하지 않으니 넘어가도록 하겠습니다.

# %% [markdown]
# ### self 짚고 넘어가기
#
# self는 인스턴스 자기 자신을 의미합니다. 다음 코드가 있습니다.
#
# class Person:
#
# def __init__(self):
#
# self.hello = ‘안녕하세요’
#
# 여기서 self.hello에 ‘안녕하세요’라는 속성을 추가했는데요.
#
# 결론적으로 (self)는 Person과 동일하다고 생각하시면 되고, self.hello는 Person().hello라고 생각하시면 self에 대한 이해가 쉽다고 생각합니다.
#
# 그래도 이해가 잘 안되신다면.. 우리가 게임 캐릭터를 새로 생성할때 초기 능력치가 고정적으로 부여된다고 했을 때, 언제 어디서 어느 나라에서 만들던지 똑같은 캐릭터에는 똑같은 초기 능력치가 생성되고, 그에 대한 초기 능력치를 입력하는 것이 위의 구문이라고 생각하시면 될 것 같습니다.
#
# 조금 더 나아가는 예시로 속성을 살펴보겠습니다.
#
# 다음은 이름과 나이 주소를 입력받는 클래스이고, greeting함수를 사용해서 자기소개를 하네요

# %%
class Person:
  def __init__(self, name, age, address):
    self.hello = '안녕하세요.'  # 할당받지 않아도 됨
    self.name = name
    self.age = age
    self.address = address

	# 위의 속성에 접근할때는 self 함수가 필요
  def greeting(self):
    print(f'{self.hello} 저는 {self.address}에 살고 있는 {self.name}입니다.')

hong = Person('홍길동', 20, '제주특별자치도 서귀포시')
hong.greeting()# 안녕하세요. 저는 홍길동입니다.

print('이름:', hong.name)# 홍길동
print('나이:', hong.age) # 20
print('주소:', hong.address) # 제주특별자치도 서귀포시
# Out:
# 안녕하세요. 저는 제주특별자치도 서귀포시에 살고 있는 홍길동입니다.
# 이름: 홍길동
# 나이: 20
# 주소: 제주특별자치도 서귀포시

# %%
# 실습 과제
# *arg, **kwargs를 사용해서 위 코드를 수정해보기

# *arg만 사용
class Person:
  def __init__(self, *arg):
    self.hello = '안녕하세요.'  # 할당받지 않아도 됨
    self.name = arg[0]
    self.age = arg[1]
    self.address = arg[2]

	# 위의 속성에 접근할때는 self 함수가 필요
  def greeting(self):
    print(f'{self.hello} 저는 {self.address}에 살고 있는 {self.age}살 {self.name}입니다.')

hong = Person('홍길동', 20, '제주특별자치도 서귀포시')
hong.greeting()# 안녕하세요. 저는 홍길동입니다.
# Out:
# 안녕하세요. 저는 제주특별자치도 서귀포시에 살고 있는 20살 홍길동입니다.

# %%
# *arg와 **kwargs를 같이 사용한 코드

class Person:
  def __init__(self, *arg, **kwarg):
    self.hello = '안녕하세요.'
    self.name = arg[0]
    self.age = arg[1]
    self.address = kwarg["address"]

  def greeting(self):
    print(f'{self.hello} 저는 {self.address}에 살고 있는 {self.age}살 {self.name}입니다.')

hong = Person('짱구', 5, address = '서울특별시')
hong.greeting()
# Out:
# 안녕하세요. 저는 서울특별시에 살고 있는 5살 짱구입니다.

# %% [markdown]
# ## 2-2. 클래스를 사용하는 이유

# %% [markdown]
# 핵심은 자신이 만든 코드를 다른 사람이 손쉽게 사용할 수 있도록 설계 → 그렇게 설계가 되었다면 자신도 사용하기 더 편할 것
#
# 사실 단순히 데이터를 저장하는 수단으로만 사용하거나 분석만을 한다면 이차원 리스트나 함수형태로 분석을 하거나 함수도 안쓰는 경우도 있다.

# %% [markdown]
# 예시로 다음과 같이 코드를 짜서 데이터를 구성한다고 생각해보자
#
# 이 코드를 통해 데이터를 받고 → 데이터를 정제하고 class를 통해
#
# 1. 데이터가 들어오는 곳
# 2. 기능을 정의하는 곳
# 3. 무언가를 출력하는 곳
#
# 이 3가지가 구별되어야 가독성이 좋다는 느낌을 받는다.

# %%
#데이터
names = ["Messi", "Ramos", "Ronaldo", "Park", "Buffon"]
positions = ["MF", "DF", "CF", "WF", "GK"]
numbers = [10, 4, 7, 13, 1]

#이차원 리스트
players = [[name, position, number] for name, position, number in zip(names, positions, numbers)]
print(players)
print(players[0])

#전체 SoccerPlayer 코드
class SoccerPlayer(object):
    def __init__(self, name, position, back_number):
        self.name = name
        self.position = position
        self.back_number = back_number
    def change_back_number(self, new_number):
        print("선수의 등 번호를 변경한다: From %d to %d" % (self.back_number, new_number))
        self.back_number = new_number
    def __str__(self):
        return "Hello, My name is %s. I play in %s in center." % (self.name, self.position)

# 클래스-인스턴스
player_objects = [SoccerPlayer(name, position, number) for name, position, number in zip(names, positions, numbers)]
print(player_objects[0])
# Out:
# [['Messi', 'MF', 10], ['Ramos', 'DF', 4], ['Ronaldo', 'CF', 7], ['Park', 'WF', 13], ['Buffon', 'GK', 1]]
# ['Messi', 'MF', 10]
# Hello, My name is Messi. I play in MF in center.

# %% [markdown]
# # 3. 노트 클래스문 만들어보기

# %% [markdown]
# 클래스를 다루는 순간부터 객체지향 프로그래밍을 할 수 있다라고 하기도 한다.
# 이것을 할때 생각해봐야할것은?
#
# 1. 이 프로그램에 필요한 것은?
# 2. 어떤 기능을 넣을 것인지?
# 3. 어떤 데이터를 저장할 것인지? # 우리한테 핵심 -> 데이터가 저장되야 분석! -> 제안하거나 추가적으로 데이터를 얻을 수 있게 해야한다.
# 4. 기능은 몇개나 필요한지? # 기능 분석
# 5. (고객관점) 어떤 연령층이 사용할 것인지? #
# 6. 기타 등등
#
# * 향후 전산요청서 / 전산개발서 같은것을들 작성할때가 있을 것임
#
# * 예시 -> 구글링

# %% [markdown]
# 간단한게 보면 노트앱의 필요는 다음과 같다.
#
# 1. 노트는 뭐든 쓸수 있어야 한다. - 어떤 단어든 사용가능
# 2. 사용자가 사용할 수 있어야 한다. - 비사용자는 접근 불가 ?
# 3. 노트북은 제목이나 소제목등을 쓸수도 있다.
# 4. 트위터 같은 경우는 300자 / 그외에 한 페이지당 쓸수 있는 제한을 둘수 도 있다.
# 5. 노트는 노트북에 사용된다.
# 6. 노트가 300페이지가 이상이 되면 더 추가할수 없다.

# %% [markdown]
# [그러면 필요한 것들을 생각해보자]
#
# 1. 객체 -  사용자, 노트, 노트북
# * 사용자 정보는 얼마나 받을건지?
# * 노트 -> 지우거나 추가하는 기능 필요
# * 300페이지 정의 (생략 가능)
# * 수정기능도 필요하지 않을까 등등
#
# 노트 기능 구현하기

# %%
# 노트 기능
# 노트 -> 무언가를 메모하는 기능

class Note() :
  '''맨 처음은 아무것도 없는 초기화상태이기 때문에 wirte=none'''
  def __init__(self, write = None) :
    self.write = write
  ''' 쓰기 기능 추가 '''
  def write_function(self, write) :
    self.write = write
  ''' 모두 지우는 기능 추가 '''
  def remove_all(self) :
    self.write = ''
  ''' 작성한 내용 보기 '''
  def __str__(self) :
    return self.write

# %%
# 노트북의 기능은 ?

# 1) 노트북의 제목
# 2) 페이지수 
# 3) 노트의 저장

class NoteBook():
  '''모든 기능을 저장하기 위해 다음과 같이 init에 모두 입력'''
  def init(self, title):
    self.title = title
    self.page_number = 1
    self.notes = {} # 딕셔너리 형으로 선언 Note Page Number를 Key로 설정해서 쉽게 찾기 위함

  ''' 새로운 노트를 노트북에 추가하는 함수'''
  ''' 지금은 되게 기본 기능만 추가했지만 실제 기능구현시 많은 것을 고려해야함 '''
  ''' 7페이지면 8페이지에 추가되는 형태로 일단 구현'''
  def add_note(self, note, page = 0):
    if self.page_number < 300:
      if page == 0:
        self.note[self.page_number] = note
        self.page_number += 1

      else:
        self.notes = {page : note}
        self.page_number += 1
    else:
      print("페이지가 300페이지가 넘어서 추가할 수 없어요")

  ''' 특정 페이지 번호에 있는 노트를 제거하는 함수'''
  # 딕셔너리의 Key가 있는지 확인하고, 있다면 삭제 없으면 프린트문 사용해서 경고문장 출력
  def remove_note(self, page_number):
    if page_number in self.notes.keys():
      return self.notes.pop(page_number)
    else:
      print("삭제된 노트입니다.")

  # 현재 노트 페이지 출력
  def get_number_of_page(self):
    return len(self.notes.keys())

####### 실습 종료 #########
###########################

# %% [markdown]
# * content에 notebook.py 파일을 만들고 위의 Note클래스와 NoteBook클래스 코드 넣고 런타임 다시 돌린 뒤 아래부터 코드 실행하기

# %%
import os
os.chdir('/content/')

# %%
from notebook import Note
from notebook import NoteBook

# %%
note_book_01 = Note("안녕하세요. 송유림입니다.")
print(note_book_01)
# Out:
# 안녕하세요. 송유림입니다.

# %%
note_book_02 = Note("저는 마라탕을 좋아합니다.")
print(note_book_02)
# Out:
# 저는 마라탕을 좋아합니다.

# %%
# 다 지우기
note_book_02.remove_all()
print(note_book_02)

# %% [markdown]
# 1. 내가 노트앱 개발자 서비스 기획자라면 어떤 것을 더 개발했을까?
# 2. 기존 노트앱의 한계는 무엇일까?
# 3. 노트앱을 통해 얻을 수 있는 데이터는 무엇일까?

# %% [markdown]
# # 4. 클래스의 요소 점검해보기

# %%
# 클래스 기본

class SoccerPlayer(object) :
# 클래스를 사용한 다음 단어의 앞글자가 대문자가 되도록 작성
# object는 생략 가능

# %%
# 클래스 실행 예시

class Singer :
  def sing(self) :
    return 'Ditto'

new_jeans = Singer()
new_jeans.sing()  # Singer라는 클래스 안에 있는 sing 함수를 불러올 수 있음
# Out:
# 'Ditto'

# %% [markdown]
# ## 4-1. 커스텀 클래스 활용

# %% [markdown]
# [커스텀 클래스 활용 예시 1]
#
# 여러분들이 회원가입을 위한 것이나 데이터 처리를 할 경우 유저 데이터에 대해서 새롭게 쌓으려고 한다면 이름, 성별, 나이 등등 필요할 것
#
# -> self.이를 인스턴스 변수라 칭하자!!
#
# 만약에 데이터 마트를 구축한다. 라고 하면 이를 가지고 사용자 정보를 출력하거나
# 그리고 만약 마케팅을 한다라고 하면 다음과 같은 기능들이 있어야 할것이다.
# * 사용자에게 나이에 맞게 메일을 보낸다.
#
# * 구글 폼 -> 마케팅 -> 정보를 받아서 -> 추첨 -> 공지 -> 사용자에게 특정시간에 어떠한 마케팅을 한다.
#
# -> 분석 준비 x

# %%
# 클래스 정의
class User:
  """ 사용자 클래스 """

  def __init__(self, name, mail):
    """ 초기화 처리 """
    self.name = name
    self.mail = mail

  def print_user_info(self):
    """ 사용자 정보를 print로 출력 """
    print(" " + self.name)
    print(" " + self.mail)

# User 타입 객체 생성
user1 = User("User1", "User1@naver.kr")

# User 타입 객체 생성
print(user1.name)

# User 타입 객체 생성
user1.print_user_info()

# User 타입 객체 생성
user1.mail = "new_user1@naver.com"

# 메서드
user1.print_user_info()
# Out:
# User1
#  User1
#  User1@naver.kr
#  User1
#  new_user1@naver.com

# %%
# 커스텀 클래스 예시 2

class Pokemon_pi:
  # 피카츄의 능력치 
  strength = 20
  dexterity = 25
  vitality = 20
  energy = 15
  volt = 100

  def attact(self):
    return 'GiGiGic'

#만약 이 파일을 Nintendo.py라는 곳에 저장한뒤에 불러올수 있다.

#import Nintendo
#Jiwoo = Nintendo.Pokemon_pi
#JinHwan = Nintendo.Pokemon_pi

# 지우도 피카츄를 가지고 나도 피카츄를 가지게 된 상황
# 마약 공격을 하려면

Jiwoo = Pokemon_pi()
JinHwan = Pokemon_pi()

Jiwoo.attact()

pika = [Jiwoo.strength,Jiwoo.volt] 
print(pika)
# Out:
# [20, 100]

# %%
# 피카츄 레벨 업!!
pika_level2 = Pokemon_pi()
pika_level2.level_up()
pika_level2_stat = [pika_level2.strength, pika_level2.dexterity, pika_level2.vitality, pika_level2.energy, pika_level2.volt] 
print(pika_level2_stat)

# %% [markdown]
# ### self
#
# * self는 바로 그 클래스의 객체를 나타냄
# * 한마디로 메서드를 정의할 때는 항상 self라는 인자를 써준다고 생각하면 됨

# %%
# Self.name과 name의 차이 

class ClassExample:
    @staticmethod
    def call(self, name):  # 함수
        self.name = "self" + name  # self.name으로 파라미터와 구분
        print("self : " + self.name + " param : " + name)


a = ClassExample()  # 객체화 (ClassExample의 정보를 a에 담음)
a.call(a, "철수")
# Out:
# self : self철수 param : 철수

# %% [markdown]
# ### __ init __ 생성자
#
# * 초기화 메서드 : 따로 호출되지 않아도 자동으로 호출되는 메서드

# %%
# 생성자는 호출만 되어도 자동으로 수행됨
class Person :
  def __init__(self) :
    print('안녕')

p = Person()
# Out:
# 안녕

# %%
class MyClass:
    count = 0

    def __init__(self):
        MyClass.count += 1

    def get_count(self):
        return MyClass.count

a = MyClass()  # 1번 호출
b = MyClass()  # 2번 호출
c = MyClass()  # 3번 호출

print(a.get_count()) # 3번 호출되었기 때문에 3이 나오게 된다.

print(MyClass.count) # 직접 호출도 가능하다.
# Out:
# 3
# 3

# %% [markdown]
# ### __ str __ 생성자

# %%
# str 생성자

class text_bot:
  def __init__(self, name, job):
    self.name = name
    self.job = job

  def __str__(self):
    return "내 이름은 %s이고, 내 직업은 %s 입니다."%(self.name, self.job)

introduce = text_bot("김진환","데이터 분석가")
print(introduce)
# Out:
# 내 이름은 김진환이고, 내 직업은 데이터 분석가 입니다.

# %% [markdown]
# ### 인스턴스 변수

# %%
# 인스턴스 변수 예시

class pokamon_select:
  def __init__(self, name, hp, damage):
    self.name = name
    self.hp = hp
    self.damage = damage

# 인스턴스 변수 사용하기

pokamon_1 = pokamon_select("피카츄", 40, 5) # 피카츄만의 인스턴스 변수 정의
pokamon_2 = pokamon_select("이상해씨", 20, 2) # 이상해씨만의 인스터스 변수 정의

# %%
pokamon_1.name
# Out:
# '피카츄'

# %% [markdown]
# ### 클래스 속성과 인스턴스 속성의 차이점

# %%
## 클래스 속성과 인스턴스 속성의 차이점

# 클래스 속성 사용시 누적이 됨
class Person:
    bag = []
 
    def put_bag(self, stuff):
        self.bag.append(stuff)
 
james = Person()
james.put_bag('책')
 
maria = Person()
maria.put_bag('열쇠')
 
print(james.bag)
print(maria.bag)
# Out:
# ['책', '열쇠']
# ['책', '열쇠']

# %%
# 인스턴스 속성 사용시 각자 구성이 됨

class Person:
    def __init__(self):  
        self.bag = []    # 초기화 설정
 
    def put_bag(self, stuff):
        self.bag.append(stuff)
 
james = Person()
james.put_bag('책')
 
maria = Person()
maria.put_bag('열쇠')
 
print(james.bag)
print(maria.bag)

# ['책']
# ['열쇠']
# Out:
# ['책']
# ['열쇠']

# %% [markdown]
# # 5. 메서드

# %% [markdown]
# 메서드는 클래스 내부에 정의한 함수로, 클래스 안에 여러 개를 만들 수 있음.
# * 메서드가 일반 함수와 다른점은 전달값 부분에 첫번째로 self를 넣는다는 점
# * 메서드 안에서 self.로 인스턴스 변수에 접근할 수 있음

# %%
class pokamon_select_update:
  def __init__(self, name, hp, damage):
    self.name = name
    self.hp = hp
    self.damage = damage

  def attack(self, who):
    print(who, "를 공격합니다.", self.damage, "만큼 데미지를 입혔습니다.") # self에 영향을 받는게 있으면 self를 사용하고, 변수명에도 self를 적용시킨다.

pokamon_1 = pokamon_select_update("피카츄", 40, 5) # 피카츄만의 인스턴스 변수 정의
pokamon_1.attack("파이리")

# 파이리를 공격합니다. 5만큼 데미지를 입혔습니다.
# Out:
# 파이리 를 공격합니다. 5 만큼 데미지를 입혔습니다.

# %% [markdown]
# ## 클래스 메서드
#
# 클래스 메서드는 다음과 같이 메서드 위에 @classmethod를 붙인다.
#
# 이 때 클래스 매서드에는 cls를 지정합니다. -> cls는 class에서 따온다.

# %%
class Person:
    count = 0    # 클래스 속성
 
    def __init__(self):
        Person.count += 1    # 인스턴스가 만들어질 때
                             # 클래스 속성 count에 1을 더함
 
    @classmethod
    def print_count(cls):
        print('{0}명 생성되었습니다.'.format(cls.count))    # cls로 클래스 속성에 접근

# %%
james = Person()
maria = Person()
 
Person.print_count()    # 2명 생성되었습니다.
# Out:
# 2명 생성되었습니다.

# %%
# cls가 사용되는 순간 현재 class의 클래스 속성에 count에 접근할 수 있음
# 그래서 print_count 메서드를 호출하면 '~명이 생성되었습니다.'가 출력됨
# Person,print_count()가 그 결과

# 클래스 메서드는 정적 메서드 처럼 인스턴스 없이 호출 가능

# 그러나 클래스 메서드는 메서드 안에서 클래스 속성이나 클래스 메서드에 접근할 때 사용됨
# cls는 가장 중요한 부분인데 메서드 안에서 현재 클래스의 인스턴스를 만들 수도 있음

# %%
class Person:
    count = 0    # 클래스 속성
 
    def __init__(self):
        Person.count += 1    # 인스턴스가 만들어질 때
                             # 클래스 속성 count에 1을 더함
 
    @classmethod
    def print_count(cls):
        print('{0}명 생성되었습니다.'.format(cls.count))    # cls로 클래스 속성에 접근
     
     
    @classmethod
    def create(cls):
        p = cls()    # cls()로 인스턴스 생성 = Person
        return p
        
 
james = Person()
maria = Person()
Person.print_count()    # 2명 생성되었습니다.
# Out:
# 2명 생성되었습니다.

# %%
Person.create()  # cls()로 p라는 인스턴스 생성 -> 현재 Person 클래스를 불러옴
Person.print_count()    # 3명 생성되었습니다.
# Out:
# 3명 생성되었습니다.

# %% [markdown]
# ## 비공개 속성

# %% [markdown]
# 클래스 바깥에서는 접근할 수 없고 클래스 내에서만 사용하는 속성으로
#
# 고객이 중요하게 생각하는 정보(요즘 같이 인터넷뱅킹, 스마트뱅킹, 비트코인지갑 등)가 많은 이 때에는 더더욱이 잔액관리가 중요합니다.
#
# 이러한 정보를 사용하는 방법은 속성이름 앞에 __속성명 으로 사용하면 됩니다.

# %%
# 비공개 속성 실습
# 비공개 속성은 앞에 언더바 두 개(__)를 붙이면 됨
# 여기서 비공개 속성은 __wallet

class Person:
    def __init__(self, name, age, address, wallet):
        self.name = name
        self.age = age
        self.address = address
        self.__wallet = wallet    # 변수 앞에 __를 붙여서 비공개 속성으로 만듦
 
    def pay(self, amount):
        self.__wallet -= amount   # 비공개 속성은 클래스 안의 메서드에서만 접근할 수 있음
        print(amount, '원을 출금하여', self.__wallet, '원 남았네요.')
 
maria = Person('마리아', 20, '서울시 서초구 반포동', 10000)
maria.pay(3000)
# Out:
# 3000 원을 출금하여 7000 원 남았네요.

# %%
# 일반 속성을 잘 불러와짐
print(maria.name)
print(maria.age)
print(maria.address)
# Out:
# 마리아
# 20
# 서울시 서초구 반포동

# %%
# 비공개 속성으로 만든 __wallet은 불러올 수 없음
print(maria.__wallet)
maria.__wallet
maria.wallet
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-1b740e05b8de> in <cell line: 2>()
#       1 # 비공개 속성으로 만든 __wallet은 불러올 수 없음
# ----> 2 print(maria.__wallet)
#       3 maria.__wallet
#       4 maria.wallet
#
# AttributeError: 'Person' object has no attribute '__wallet'

# %%
# (참고) 속성 뿐만 아니라 메서드도 이름이 __로 시작되면 바깥에서 호출이 불가

class Person:
    def __greeting(self):
        print('Hello')
 
    def hello(self):
        self.__greeting()    # 클래스 안에서는 비공개 메서드를 호출할 수 있음
 
james = Person()
james.__greeting()    # 에러: 클래스 바깥에서는 비공개 메서드를 호출할 수 없음
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-fb167414e39d> in <cell line: 11>()
#       9
#      10 james = Person()
# ---> 11 james.__greeting()    # 에러: 클래스 바깥에서는 비공개 메서드를 호출할 수 없음
#
# AttributeError: 'Person' object has no attribute '__greeting'

# %% [markdown]
# ### __test 비공개 속성 - 가시성/은닉성
#
# 객체의 정보를 볼 수 있는 레벨을 조절해서 객체의 정보접근을 숨기는 것을 말합니다.
#
# 이 특징은 캡슐화, 정보은닉과 연결되어있습니다.
#
# 객체의 재사용을 하려면 결국 각 객체가 무슨 역할을 하는지 알아야합니다.
# 그러나 동시에 구현의 세부적인 내용을 알필요는 없죠
#
# 단지 사용하는 방법을 일단 알며 됩니다. 이러한 개념을 캡슐화라고하며, 객체의 세부내용은 모른체 객체의 사용법만 알고 사용한다는 뜻입니다.
#
# 이렇게 사용되는 프로그램이 꽤 많죠;; ㅎㅎ
#
# 동시에 핵심적인 정보는 숨겨야할 때가 있습니다. 이를 정보 은닉이라고 합니다. 외부에서 코드 내부를 볼 수 없게 하기 위한 개념인거죠
# 뭐.. 어쨋든 캡슐화와 정보은닉은 결국 코드의 내부 구현을 잘해서 외부에서도 쉽게 사용되지만 세부적인 내용은 모르게 하는 측면해서 비슷한 의미로 사용됩니다.

# %% [markdown]
# ## 어떤 클래스의 인스턴스인지?

# %% [markdown]
# * 일단 객체(인스턴스)가 어떤 클래스로 부터 만들어졌는지 확인할 수 있게 isinstance()함수를 제공합니다.
#
# * isinstance()함수는 첫번째 매개변수에 객체(인스턴스), 두번째매개변수에 클래스를 입력합니다.
#
# * isinstance(인스턴스, 클래스)

# %%
# isinstance 사용
# 이 때 인스턴스가 해당 클래스를 기반으로 만들어졌으면 True 전혀 상관이 없으면 False를 리턴합니다.

# Student 클래스 선언
class Student:
  def __init__(self):
    pass

# Student 선언
student = Student()

# 인스턴스 확인하기
print(f"{isinstance(student, Student)} 입니다.")  # student, Student의 순서도 중요
# Out:
# True 입니다.

# %% [markdown]
# # 연습문제

# %% [markdown]
# ## 연습문제 1

# %%
# 연습문제 01

class SoccerPlayer:
  def __init__(self, name, position, back_number):
    self.name = name
    self.position = position
    self.back_number = back_number

  def change_back_number(self, back_number):
    self.back_number = back_number

player1 = SoccerPlayer("KangInLee", "MF", "7")
print(f"현재 선수의 등번호는 {player1.back_number} 입니다.")
player1.change_back_number(5)

# 1) 현재 선수의 등번호는?
# 2) 에러 발생
# 3) 현재 선수의 등번호는 5 입니다.
# 4) 현재 선수의 등번호는 None 입니다.
# 5) 현재 선수의 등번호는 7 입니다.

# 답은 5번
# print()문 다음에 player1.change_back_number(5)가 실행되었지만 그 뒤에 print문이 없어서
# 5로 변경된건 결과에 나오지 않음
# Out:
# 현재 선수의 등번호는 7 입니다.

# %% [markdown]
# ## 연습문제 2

# %%
# 연습문제 2

class house_password():
  def __init__(self):
    self.password = 9999

  def set_password(self, new_password):
    self.password = new_password
    print("패스워드가 변경되었습니다.")

  def get_password(self):
    print(f"현재 패스워드는 {password}입니다.")

my_house = house_password()
my_house.get_password()
my_house.set_password(1234)
print(my_house.password)

# def get_password의 f-string문에서 그냥 password는 없음
# self.password로 변경되어야함
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f1c611fd24e1> in <cell line: 15>()
#      13
#      14 my_house = house_password()
# ---> 15 my_house.get_password() #여기서 오류 password가 없음;;??
#      16 my_house.set_password(1234)
#      17 print(my_house.password)
#
# <ipython-input-14-f1c611fd24e1> in get_password(self)
#      10
#      11   def get_password(self):
# ---> 12     print(f"현재 패스워드는 {password}입니다.")
#      13
#      14 my_house = house_password()
#
# NameError: name 'password' is not defined

# %%
# f-string을 self.password로 바꿨을 때
class house_password():
  def __init__(self):
    self.password = 9999

  def set_password(self, new_password):
    self.password = new_password
    print("패스워드가 변경되었습니다.")

  def get_password(self):
    print(f"현재 패스워드는 {self.password}입니다.")

my_house = house_password()
my_house.get_password()
my_house.set_password(1234)
print(my_house.password)
# Out:
# 현재 패스워드는 9999입니다.
# 패스워드가 변경되었습니다.
# 1234

# %% [markdown]
# ## 연습문제 3

# %%
# 연습문제 3

class house_password():
  def __init__(self):
    self.__password = 9999

  def set_password(self, new_password):
    self.__password = new_password
    print("패스워드가 변경되었습니다.")

#self를 넣어야 제대로 작동 그러나 또 오류
  def get_password(self):
    print(f"현재 패스워드는 {self.__password}입니다.")

my_house = house_password()
my_house.get_password()
my_house.set_password(1234)
print(my_house.password)
# Out:
# 현재 패스워드는 9999입니다.
# 패스워드가 변경되었습니다.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-c4ed0f358bb3> in <cell line: 18>()
#      16 my_house.get_password()
#      17 my_house.set_password(1234)
# ---> 18 print(my_house.password)
#
# AttributeError: 'house_password' object has no attribute 'password'

# %%
# 위 코드를 이렇게 변경하면 실행됨

class house_password():
  def __init__(self):
    self.password = 9999

  def set_password(self, new_password):
    self.password = new_password
    print("패스워드가 변경되었습니다.")

  def get_password(self):
    print(f"현재 패스워드는 {self.password}입니다.")

my_house = house_password()
my_house.get_password()
my_house.set_password(1234)
print(my_house.password)
# Out:
# 현재 패스워드는 9999입니다.
# 패스워드가 변경되었습니다.
# 1234

# %% [markdown]
# ## 연습문제 4

# %%
# 연습문제 4

class Terran(object):
  def __init__(self, mineral):
    self.scv = 4
    self.marine = 0
    self.medic = 0
    self.mineral = mineral

  def command(self, SCV = False):
    self.mineral += 8*self.scv
    if SCV:
      self.scv += 1
      self.mineral -= 10

  def barrack(self, Marine=False, Medic =False):
    self.mineral += 8 * self.scv

    if Medic:
      self.medic += 1
      self.mineral -= 25
    
    if Marine:
      self.marine += 1
      self.mineral -= 15

  def check_source(self):
    print(f"Mineral이 {self.mineral}만큼 있습니다.")

# %%
SlayerS_BoxeR = Terran(50)
SlayerS_BoxeR.command(True)
SlayerS_BoxeR.barrack(True, True)
SlayerS_BoxeR.check_source()
# Out:
# Mineral이 72만큼 있습니다.

# %% [markdown]
# # 실습

# %% [markdown]
# ## 실습 1. 포켓몬게임

# %% [markdown]
# https://happydata1510.notion.site/happydata1510/1-919ee0a819c9435db129598e6c72c746

# %%
# 포켓몬 클래스화 하기

class pokemon_select:
  def __init__(self, name, hp, attack, defense, s_attack, s_defense, speed):
    # 메서드에 정의한 변수는 인스턴스 변수
    self.name = name 
    self.hp = hp
    self.defense = defense
    self.s_attack = s_attack
    self.s_defense = s_defense
    self.speed = speed
    print(f"{self.name}을 생성했습니다.")
    print(f"체력은 {self.hp}, 공격력은 {self.defense}, 방어력은 {self.defense}, 특수공격은 {self.s_attack}, 특수방어는 {self.s_defense}, 민첩성은 {self.speed} 입니다.")

# %%
# 포켓몬 만들기

pikachu_025 = pokemon_select("피카츄", 35, 55, 40, 50, 50, 90)
charmander_004 = pokemon_select("파이리", 35, 52, 43, 60, 50, 65)
squirtle_007 = pokemon_select("꼬부기", 44, 48, 65, 50, 64, 43)
# Out:
# 피카츄을 생성했습니다.
# 체력은 35, 공격력은 40, 방어력은 40, 특수공격은 50, 특수방어는 50, 민첩성은 90 입니다.
# 파이리을 생성했습니다.
# 체력은 35, 공격력은 43, 방어력은 43, 특수공격은 60, 특수방어는 50, 민첩성은 65 입니다.
# 꼬부기을 생성했습니다.
# 체력은 44, 공격력은 65, 방어력은 65, 특수공격은 50, 특수방어는 64, 민첩성은 43 입니다.

# %%
# 만약 전체값 중 일부만 넣는다면?

pikachu_025_test = pokemon_select("피카츄", 35, 55, 40, 50, 50) 

# 에러 발생 : 어떤 argument가 빠졌는지 알려줌
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-5504dbfb25d3> in <cell line: 3>()
#       1 # 만약 전체값 중 일부만 넣는다면?
#       2
# ----> 3 pikachu_025_test = pokemon_select("피카츄", 35, 55, 40, 50, 50)
#       4
#       5 # 에러 발생
#
# TypeError: pokemon_select.__init__() missing 1 required positional argument: 'speed'

# %%
# 포켓몬 확인해보기
pikachu_025.name
# Out:
# '피카츄'

# %%
# 생성된 피카츄의 능력치 데이터에 접근 및 레벨업 추가
pikachu_025.level_up = True
pikachu_025.level_up
# Out:
# True

# %%
# 피카츄를 라이츄로 진화시키기

if pikachu_025.level_up == True:
  print("피카츄는 라이츄로 진화할수 있습니다. 레벨업을 하시겠습니까?")

# %%
# 위의 문장을 좀 더 게임처럼 만들려면 어떻게 할까요?

if pikachu_025.level_up == True:
  level_up_check = input("피카츄는 라이츄로 진화할수 있습니다. 레벨업을 하시겠습니까?")
  if level_up_check == "예":
    print("라이츄로 진화했습니다.")
  else:
    print("아직 피카츄가 좋아! 다음 기회에 진화해주세요") 

# 하지만 이 기능은 피카츄에게만 단독으로 부여된거라
# 다른 포켓몬은 활용할 수 없어요
# Out:
# 피카츄는 라이츄로 진화할수 있습니다. 레벨업을 하시겠습니까?아니요
# 아직 피카츄가 좋아! 다음 기회에 진화해주세요

# %%
class pokemon_select:
  def __init__(self, name, hp, attack, defense, s_attack, s_defense, speed):
    # 메서드에 정의한 변수는 인스턴스 변수
    self.name = name 
    self.hp = hp
    self.attack = attack
    self.defense = defense
    self.s_attack = s_attack
    self.s_defense = s_defense
    self.speed = speed
    print(f"{self.name}을 생성했습니다.")
    print(f"체력은 {self.hp}, 공격력은 {self.defense}, 방어력은 {self.defense}, 특수공격은 {self.s_attack}, 특수방어는 {self.s_defense}, 민첩성은 {self.speed} 입니다.")
 
  def attacked(self, name, attack_basic, attack):
    print(f'{self.name}이(가) {attack_basic}을 했습니다. 데미지는 {self.attack} 만큼 피해를 주었습니다.' )

  def damaged(self, damage):
    print(f"{self.name}가 {damage}만큼 피해를 입었습니다.")
    self.hp -= damage
    # 남은 채력 출력
    print(f"현재 {self.name}의 체력은 {self.hp}이(가) 남았습니다. ")
    if self.hp <= 0:
      print(f"{self.name}의 체력이 0이 되었습니다. 게임을 다시 시작해주세요")

# %%
# 생성된 피카츄
pikachu_025 = pokemon_select("피카츄", 35, 55, 40, 50, 50, 90)
# Out:
# 피카츄을 생성했습니다.
# 체력은 35, 공격력은 40, 방어력은 40, 특수공격은 50, 특수방어는 50, 민첩성은 90 입니다.

# %%
# 상대방의 방어력은 아직 반영 안함
pikachu_025.attacked(pikachu_025.name, "기본공격", pikachu_025.attack)
# Out:
# 피카츄이(가) 기본공격을 했습니다. 데미지는 55 만큼 피해를 주었습니다.

# %%
# 상대방의 공격력은 아직 반영 안함
pikachu_025.damaged(30)
# Out:
# 피카츄가 30만큼 피해를 입었습니다.
# 현재 피카츄의 체력은 5이(가) 남았습니다.

# %%
# 다시 상대편 차례라 공격
pikachu_025.damaged(5)
# Out:
# 피카츄가 5만큼 피해를 입었습니다.
# 현재 피카츄의 체력은 0이(가) 남았습니다.
# 피카츄의 체력이 0이 되었습니다. 게임을 다시 시작해주세요

# %% [markdown]
# ## 실습 2. 차량 등록기
#
# 1. 총 주차 가능 대수인 capacity는 객체를 생성할때 전달받아 인스턴스 변수로 정의
# 2. 현재 등록된 차량을 관리하는 count는 객체를 생성하여 0으로 정의
# 3. 객체를 생성할때 등록 가능한 대수 출력
# 4. 차를 신규 등록하는 register()메서드 생성
# 5. 신규 등록시 등록 현황을 출력
# 6. 총 주차가능대수가 초과할 경우 “등록할 수 없습니다.” 메세지 출력

# %%
class ParkingManager :
  count = 0
  def __init__(self, capacity) :
    self.capacity = capacity
    print(f'현재 {self.capacity}대를 등록할 수 있습니다.')
  
  def register(self) :
    if self.capacity > self.count :
      self.count += 1
      print(f'총 {self.count}대가 주차되었습니다.')
    else :
      print('등록할 수 없습니다.')

# %%
manager = ParkingManager(5)
for i in range(4):
  manager.register()
# Out:
# 현재 5대를 등록할 수 있습니다.
# 총 1대가 주차되었습니다.
# 총 2대가 주차되었습니다.
# 총 3대가 주차되었습니다.
# 총 4대가 주차되었습니다.

# %%
# 강사님 답안
class ParkingManager:
  # 주차정보 초기화
  def __init__(self, capacity):
    self.capacity = capacity # 총 주차 가능 대수
    self.count = 0 #현재 등록된 차량수
    print(f"총 {capacity}대를 등록할 수 있어요")
  # 신규 차량 등록
  def register(self):
    if self.count >= self.capacity: #5
      print("모두 등록되었어요...")
      return 
    self.count += 1
    print(f'신규 차량이 등록되었습니다. ({self.count}/{self.capacity})')

#테스트

manager = ParkingManager(5)
for i in range(6):
  manager.register()
# Out:
# 총 5대를 등록할 수 있어요
# 신규 차량이 등록되었습니다. (1/5)
# 신규 차량이 등록되었습니다. (2/5)
# 신규 차량이 등록되었습니다. (3/5)
# 신규 차량이 등록되었습니다. (4/5)
# 신규 차량이 등록되었습니다. (5/5)
# 모두 등록되었어요...

# %% [markdown]
# ## 실습 3. 부동산 프로그램
#
# 1. self 생성자로 인스턴스 변수를 정의합니다.
# 2. 매물정보를 표시하는 show_detail에서는 인스턴스 변수를 출력하여 부동산 정보를 표시하게 합니다.
# 3. 네이버 부동산/생각해서 자신이 관심있는 매물 3가지의 정보를 받아 몇가지 매물이 있는 지 확인하고, 각 부동산 정보를 출력합니다.

# %%
#해당 코드를 사용해서 부동산 코드를 만드세요

class House:

#매출 초기화 : 위치, 건물종류 , 매물종류, 가격, 준공연도
  def __init__(self, location, house_type, deal_type, price, completion_year):
	  pass

#매출 정보 표시
  def show_detail(self):
		pass

# %%
# 강사님 답안
class House:
  #매출 초기화 : 위치, 건물종류 , 매물종류, 가격, 준공연도
  def __init__(self, location, house_type, deal_type, price, completion_year):
    self.location = location
    self.house_type = house_type
    self.deal_type = deal_type
    self.price = price
    self.completion_year = completion_year

  #매출 정보 표시
  def show_detail(self):
    print(self.location, self.house_type, self.deal_type, self.price, self.completion_year)

houses = []
house1 = House("강남", "아파트", "매매", "10.5억", "2010년")
house2 = House("강남", "빌라", "전세", "12.5억", "2015년")
house3 = House("강남", "빌라", "전세", "12.5억", "2015년")

houses.append(house1)
houses.append(house2)
houses.append(house3)

print(f"총 {len(houses)} 개의 매물이 있습니다.")

for house in houses:
  house.show_detail()
# Out:
# 총 3 개의 매물이 있습니다.
# 강남 아파트 매매 10.5억 2010년
# 강남 빌라 전세 12.5억 2015년
# 강남 빌라 전세 12.5억 2015년

# %% [markdown]
# # 상속

# %% [markdown]
# 상속은 어떤 클래스가 다른 클래스의 성질을 물려받는 것.
# 유산을 상속 받는 것과 동일하다고 생각하며 됨
#
# 어떤 클래스를 만들때 처음부터 다른 클래스로 부터 상속받게 만들면 좀 더 쓸만한 클래스를 만들수 있음
#
# * 기능을 물려줌 - base class(기반 클래스) - 부모 클래스, 슈퍼클래스
# * 상속을 받아 새롭게 만듬 - derived class(파생 클래스) - 자식 클래스, 서브 클래스
#
# [상속을 사용하는 이유]
# * 결국 기존 기능을 재사용하고, 중복되는 기능을 만들지 않아도 되기 때문

# %%
# 기본 문법

# inheritance 상속

class Person(object):
  pass

# class라는 예약어 다음에 클래스명으로 Person을 쓰고, 
# ()안에 object를 입력하였다.
# 여기서 object가 바로 부모 클래스이다.

# 사실 object는 파이썬에서 사용하는 
# 가장 기본 객체(base object - 기반 객체라고도 함)
# 파이썬 언어는 객체지향 프로그래밍을 모든 변수는 객체이다.

# 예를 들어 파이썬의 문자열 형 변수에 대해 다음과 같이 객체 이름을 확인할 수 있다.

a = 'abc'
type(a) -> class 'str'

# 지금까지 'abc'를 우리는 문자열형 문자열 자료라고 불렀는데, 
# 내부적으로는 객체로 처리된것이다.
# 파이썬의 모든 객체는 object객체를 상속한다.

# %% [markdown]
# * 상속 클래스 작성법
#
#   class 기반클래스이름 :  # 부모
#
#     코드
#
#   class 파생클래스이름(기반클래스이름) :  # 자식
#
#     코드

# %%
# 상속 클래스 작성법
class 기반클래스이름 :  # 부모
  코드

class 파생클래스이름(기반클래스이름) :  # 자식
  코드

# %%
class Person(object):  # 부모
  def __init__(self, name, age):
    self.name = name
    self.age = age

class Korean(Person):  # 자식
  pass

first_korean = Korean("Dawon",4)
print(first_korean.age)

# 이 코드는 먼저 Person class를 생성한 것
# Person 클래스는 생성자 __init__() 함수를 만들어 name과 age를 만들었다는 것은 이제 알것이다.

# 여기서 중요한 것은 지금까지는 그러지 않았지만 클래스안에 클래스를 볼수 있다.
##### Korean클래스를 만들면서 Person클래스를 상속받는것이다.

# 그리고 pass를 사용하여 별도의 내용 없이 클래스만 존재하는 것을 만들었다.
# 결국 Korean은 아무런 내용이 없는 클래스인데, Korean(Person)을 사용하게 되면서
# Korean은 Person이 가지고 있는 생성자를 그래도 사용할수 있게 된것이다.
# Out:
# 4

# %% [markdown]
# ## 상속 _ 예제 1

# %%
# 예제 1
# Person 부모 클래스

class Person(object): # 부모 클래스 선언

  # 초기 메서드
  def __init__(self, name, age, gender):
    self.name = name
    self.age = age
    self.gender = gender

  # 출력 메서드
  def about_me(self): # 메서드 선언
    print(f"안녕하세요 제 이름은 {name}이고, 나이는 {age}이고, 성별은 {gender}입니다.")

# %%
# Person클래스를 상속 받을 자식 클래스 만들기

class Empolyee(Person):
  # Employee 초기 메서드
  def __init__(self, name, age, gender, salary, hire_date):
    # Person의 초기메서드
    super().__init__(name, age, gender)
    self.salary = salary
    self.hire_date = hire_date
  
  def do_work(self):
    print("근무시간 이에요")

  def about_me(self):
    super().about_me()
    print(f"저의 월급은 {self.salary}이고, 제 입사날짜는 {self.hire_date}입니다.")

# %%
# Person 클래스가 단순히 사람에 대한 정보를 정의했다면 
# Employee 클래스는 사람에 대한 정의를 부모 클래스도 부터 받아서, 입사날짜와 월급에 대한 변수를 추가하였습니다.
# 즉 부모클래스의 __init__함수를 재정의 했습니다.

# 이때 부모 클래스의 __init__()함수를 그대로 사용하려면 별도의 __init__함수를 만들지 않아도 됩니다.
# 하지만 기존 함수를 사용하면서 새로운 내용을 추가하려면 자식 클래스에 __init__함수를 생성할때 super().__init__(매개변수)라고 입력합니다.
# 여기서 super는 부모클래스를 가르키고, 즉, 부모 클래스의 __init__()함수를 그대로 사용한다는 뜻이다.

# 슈퍼맨이 돌아왔다라는 TV프로그램을 생각하시면 좀더 빠르게 기억하지 않을까 싶습니다.

# 그리고 그 아래에는 자식 클래스에 필요한 새로운 변수를 추가합니다.
# 이러한 함수의 재정의를 오버라이딩이라고 합니다.

# 오버라이딩이란 상속 시 함수 이름과 필요한 매개변수는 그대로 유지되면서 함수의 수행 코드는 변경하는 것이다.
# 같은 방식으로 about_me() 함수가 오버라이딩 된 것을 확인할 수 있다.
# Person과 Employee에 대한 설명을 추가한 것이다.

# 위 코드들은 설명의 용이성을 위해 텍스트 형태의 설명만 추가하였지만 실제로는 프로그램에 사용하기 위한 다양한 기능이 추가될 수 있다.

# do_work처럼 자식 클래스에만 필요한 새로운 함수를 생성할 수도 있습니다.
# 앞서 설명했듯 자식 클래스는 부모 클래스보다 더 많은 일들을 합니다.
# 따라서 자식 클래스를 설정할때는 부모클래스보다 더 많은 일을 수행할수 있게 코드를 작성해야합니다.

# 이외에도 다양한 상속기능을 지원합니다.
# 1개이상의 클래스 특징을 상속하는, 다중상속의 개념도 있는데 이는 데이터 분석단계에서는 필요하지 않기 때문에 밑에서 예시만 배우고 넘어가기로 합니다.

# %% [markdown]
# ## 상속 _ 예제 2

# %%
# 예제2. 피카츄에서 라이츄로 진화하기
# 라이츄는 피카츄 스킬도 가지고 있음

class Pikachu:
    def skill(self):
        print('전기충격')
 
class Lichu(Pikachu):
    def new_skill(self):
        print('몸통 박치기')
 
Jiwoo = Lichu()
Jiwoo.skill()    # 안녕하세요.: 기반 클래스 Person의 메서드 호출
Jiwoo.new_skill()       # 공부하기: 파생 클래스 Student에 추가한 study 메서드

#원래 Lichu에는 전기충격이 없지만 Pikachu의 속성을 그대로 가져왔으므로 호출할 수 있었음
# Out:
# 전기충격
# 몸통 박치기

# %%
# 상속 관계 확인하기 - issubclass
issubclass(Lichu, Pikachu) # 순서를 지켜아함, 거꾸로하면 False 나옴
# Out:
# True

# %% [markdown]
# ## 상속 _ 연습문제 1

# %%
# 연습문제 1

class Marvel(object):
  def __init__(self, name, characteristic):
    self.name = name
    self.characteristic = characteristic

  def __str__(self):
    return f"나의 마블 캐릭터 이름은 {self.name}입니다. 저의 특수 능력치는 {self.characteristic} 입니다."

class Villain(Marvel):
  pass

first_villain = Villain("타노스","인피티니 건틀랫")
print(first_villain)

#1) 나의 마블 캐릭터 이름은 타노스입니다. 저의 특수 능력치는 인피티니 건틀랫 입니다.
#2) 나의 마블 캐릭터 이름은 타노스입니다. 저의 특수 능력치는 None 입니다.
#3) None
#4) pass
#5) 에러발생

#  답은 1번
# Out:
# 나의 마블 캐릭터 이름은 타노스입니다. 저의 특수 능력치는 인피티니 건틀랫 입니다.

# %% [markdown]
# ## 상속 _ 연습문제 2

# %%
# 연습문제 2

class TV(object):
  def __init__(self, size, year, company):
    self.size = size
    self.year = year
    self.company = company

  def describe(self):
    print(self.company + "에서 만든 " + self.year + "년형 " + self.size + "인치 TV")

class Laptop(TV):
  def describe(self):
    print(self.company + "에서 만든 "  + self.year + "년형 " + self.size + "인치 노트북")

LG_TV = TV("32", "2022", "LG")
LG_TV.describe()

samsung_microwave = Laptop("15", "2023", "Samsung")
samsung_microwave.describe()


#1. LG에서 만든 2022년형15인치 TV
#   Samsung에서 만든2023년형32인치 노트북

#2. LG에서 만든 2022년형15인치 TV
#   Samsung에서 만든 2023년형 15인치 노트북

#3. LG에서 만든 2022년형 32인치 TV
#   Samsung에서 만든 2023년형 32인치 노트북

#4. LG에서 만든 2022년형 32인치 TV
#   Samsung에서 만든 2023년형 15인치 노트북

#5. LG에서 만든 2023년형 32인치 TV
#   Samsung에서 만든 2022년형 15인치 노트북

# 답은 4번
# Out:
# LG에서 만든 2022년형 32인치 TV
# Samsung에서 만든 2023년형 15인치 노트북

# %% [markdown]
# ## 속성 _ 연습문제 3

# %%
class Company:
  def __init__(self):
    self.work = True
    self.name = 'Jane'
    self.company_name = 'woman'

  def retire(self):
    self.work = False

class Employee(Company):
  def __init__(self, name, company_name):
    super().__init__()
    self.name = name
    self.company_name = company_name

  def introduce(self):
    if self.work == True:
      print('취업 성공')
      print(f'이름은 {self.name}입니다.') 
      print(f'회사는 {self.company_name}입니다.') 

    if self.work == False:
      print(f'직업을 구하는 중..')

em = Employee('김진환', '위니브')
em.retire()
em.introduce()
Employee('김진환', '위니브').introduce()

# 1. 취업성공
#    이름은 김진환입니다.
#    회사는 위니브입니다.
#    직업을 구하는 중..

# 2. 직업을 구하는 중..
#    취업성공
#    이름은 김진환입니다.
#    회사는 위니브입니다.

# 3. 직업을 구하는 중..
#    이름은 김진환입니다.
#    회사는 위니브입니다.
#    직업을 구하는 중..

# 4. error

# 답은 3번
# Out:
# 직업을 구하는 중..
# 취업 성공
# 이름은 김진환입니다.
# 회사는 위니브입니다.

# %% [markdown]
# # 기반 클래스 속성

# %% [markdown]
# 이번에는 기반 클래스에 들어있는 인스턴스 속성을 사용해보겠습니다. 다음과 같이 Person 클래스에 hello 속성이 있고, Person 클래스를 상속받아 Student 클래스를 만듭니다. 그다음에 Student로 인스턴스를 만들고 hello 속성에 접근해봅니다.

# %%
class Person:
    def __init__(self):
        print('Person __init__')
        self.hello = '안녕하세요.'
 
class Student(Person):
    def __init__(self):
        print('Student __init__')
        self.school = '데이터 분석 스쿨입니다.'
 
james = Student()
print(james.school)
print(james.hello)    # 기반 클래스의 속성을 출력하려고 하면 에러가 발생함

# print(james.hello)에서 에러가 남 -> 왜 나는걸까?
# Person의 __init__메서드가 호출되지 않았기 때문에 
# Student의 안녕하세요도 출력되지 않아 속성도 많들어지지 않음
# Out:
# Student __init__
# 데이터 분석 스쿨입니다.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-6308304c285c> in <cell line: 13>()
#      11 james = Student()
#      12 print(james.school)
# ---> 13 print(james.hello)    # 기반 클래스의 속성을 출력하려고 하면 에러가 발생함
#      14
#      15 # print(james.hello)에서 에러가 남
#
# AttributeError: 'Student' object has no attribute 'hello'

# %%
#super()를 사용하지 않으려면?
#파생되는 클래스에서 __init__메서드를 생략하면 자동 호출됨
#그래서 맨처음 클래스에서 봤던 예제에서 Pikachu의 속성이 가져오게 됨

class Person:
    def __init__(self):
        print('Person __init__')
        self.hello = '안녕하세요.'
 
class Student(Person):
    pass
 
james = Student()
print(james.hello)
# Out:
# Person __init__
# 안녕하세요.

# %%
# super()를 활용하여 __init__ 메서드 호출

class Person:
    def __init__(self):
        print('Person __init__')
        self.hello = '안녕하세요.'
 
class Student(Person):
    def __init__(self):
        print('Student __init__')
        super().__init__()                # super()로 기반 클래스의 __init__ 메서드 호출
        self.school = '파이썬 코딩 도장'
 
james = Student()
print(james.school)
print(james.hello)
# Out:
# Student __init__
# Person __init__
# 파이썬 코딩 도장
# 안녕하세요.
